# %% [markdown]
# ## Stock Return Prediction using Fundamental Data

# %% [markdown]
# ### Introduction

# %%
# This is a continuation of Part I of the series on Stock Return Prediction using Fundamental Data
# Please refer to Part I of this series first before going through this section

# This projects seeks to uncover key fundamental ratios and variables that significantly drive stock returns for the
# medium and long term.
# Please note this is not a trading strategy
# Datsets were downloaded in piecemeal, four different datasets (fundamental stock data ) downloaded from simfin.com 
# (https://simfin.com/) Whereas return data were scraped from yahoo finance

# %% [markdown]
# ## Part II Using a Resampled Dataset

# %%
# Part II of the series on Stock Prediction using fundamental data employs several strategies to handle the effect of
# imbalanced data on the output among which are oversampling the undersampled class, using ensemble models, hyperparamter
# tuning, feature selection among others.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report,accuracy_score
import scikitplot as skplt
from sklearn.metrics import *
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn import preprocessing, metrics
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.model_selection import GridSearchCV
import scikitplot as skplt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import SelectFromModel

# %%
dataset1 = pd.read_csv('dataset.csv')

# %%
dataset1.head()
# Out:
#    Unnamed: 0                   Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0           0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1           1       21st Century Fox    FOX                     0.0545
# 2           2        3D SYSTEMS CORP    DDD                     0.0779
# 3           3                     3M    MMM                     0.0585
# 4           4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  ...   MCAP (in million, USD)  EV (in million, USD)  \
# 0                -0.2443  ...               720.839700            879.482310
# 1                -0.0141  ...             84236.546740         104151.607800
# 2                -0.0525  ...              2045.077054           1313.512819
# 3                -0.0454  ...            123317.884900         125106.677500
# 4                 2.5943  ...              1816.977159           1532.456973
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 1            14.77            3.41         20.51       0.24         0.0620
# 2            69.11            1.92        -24.24       0.42        -0.0319
# 3            15.41            3.81         24.34       0.09         0.0532
# 4           -42.78            6.02        -14.09       0.14        -0.0359
#
#    P. F-Score (TTM)    Return  Loss
# 0                 5  0.107477     0
# 1                 6  0.401115     0
# 2                 0  0.140251     0
# 3                 4 -0.190989     1
# 4                 1  0.263860     0
#
# [5 rows x 68 columns]

# %%
dataset = dataset1.drop(dataset1.columns[[0]], axis=1)

# %%
dataset.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1       21st Century Fox    FOX                     0.0545
# 2        3D SYSTEMS CORP    DDD                     0.0779
# 3                     3M    MMM                     0.0585
# 4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)  ...   \
# 0                -0.2443                  -0.1610  ...
# 1                -0.0141                  -0.0073  ...
# 2                -0.0525                   0.1345  ...
# 3                -0.0454                  -0.0502  ...
# 4                 2.5943                  12.4883  ...
#
#    MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0              720.839700            879.482310            12.00
# 1            84236.546740         104151.607800            14.77
# 2             2045.077054           1313.512819            69.11
# 3           123317.884900         125106.677500            15.41
# 4             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)  \
# 0            0.72         20.29       0.37         0.0449                 5
# 1            3.41         20.51       0.24         0.0620                 6
# 2            1.92        -24.24       0.42        -0.0319                 0
# 3            3.81         24.34       0.09         0.0532                 4
# 4            6.02        -14.09       0.14        -0.0359                 1
#
#      Return  Loss
# 0  0.107477     0
# 1  0.401115     0
# 2  0.140251     0
# 3 -0.190989     1
# 4  0.263860     0
#
# [5 rows x 67 columns]

# %%
dataset[['Loss']].plot(kind='hist');

# %%
# The graph above shows the imbalanced distribution of the Loss classes

# %%
dataset.columns.get_loc('P. F-Score (TTM)')
# Out:
# 64

# %%
dataset.groupby('Loss')['Loss'].count()/dataset['Loss'].count().sum()
# Out:
# Loss
# 0    0.221607
# 1    0.778393
# Name: Loss, dtype: float64

# %%
# Clearly the dataset is imbalanced

# %%
#plt.rcParams['figure.figsize']=(16,8)
#plt.style.use('ggplot')
#cormat = dataset.corr()
#sns.heatmap(cormat, square=True);

# %%
#Selecting the Features
X = dataset.iloc[:,2:65]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    Revenues (%chg., TTM, 1y)  COGS (%chg., TTM, 1y)  \
# 0                    -0.0178                 0.0072
# 1                     0.0545                 0.0861
# 2                     0.0779                 0.0735
# 3                     0.0585                 0.0646
# 4                    -0.0626                -0.0204
#
#    Gross Profit (%chg., TTM, 1y)  Op. Exp. (%chg., TTM, 1y)  \
# 0                        -0.0501                    -0.0294
# 1                         0.0007                     0.0238
# 2                         0.0828                     0.0655
# 3                         0.0524                     0.1339
# 4                        -0.0757                     0.1077
#
#    SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  EBIT (%chg., TTM, 1y)  \
# 0                -0.0337                0.0200                -0.2443
# 1                 0.0164                0.0000                -0.0141
# 2                 0.0814                0.0220                -0.0525
# 3                 0.1750               -0.0114                -0.0454
# 4                 0.0876                0.2346                 2.5943
#
#    EBITDA (%chg., TTM, 1y)  Interest, net (%chg., TTM, 1y)  \
# 0                  -0.1610                         -0.3353
# 1                  -0.0073                          0.0025
# 2                   0.1345                          9.1778
# 3                  -0.0502                          2.9634
# 4                  12.4883                          0.0000
#
#    Pretax Inc. (adj) (%chg., TTM, 1y)        ...         P/B (TTM)  \
# 0                             -0.4219        ...              2.72
# 1                             -0.0566        ...              4.14
# 2                             -0.0058        ...              2.33
# 3                             -0.0812        ...             11.22
# 4                              3.6213        ...              6.76
#
#    P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0        18.52              720.839700            879.482310            12.00
# 1        17.87            84236.546740         104151.607800            14.77
# 2       -25.20             2045.077054           1313.512819            69.11
# 3        22.51           123317.884900         125106.677500            15.41
# 4       -14.88             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)
# 0            0.72         20.29       0.37         0.0449                 5
# 1            3.41         20.51       0.24         0.0620                 6
# 2            1.92        -24.24       0.42        -0.0319                 0
# 3            3.81         24.34       0.09         0.0532                 4
# 4            6.02        -14.09       0.14        -0.0359                 1
#
# [5 rows x 63 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Loss, dtype: int64

# %%
dataset.groupby('Loss')['Loss'].count()
# Out:
# Loss
# 0    240
# 1    843
# Name: Loss, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Boosting the undersampled class

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X, y)
from collections import Counter

# %%
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 843), (1, 843)]

# %%
# The undersampled class (class 0) has been boosted to match the class 1

# %%
X_resampled.shape, y_resampled.shape
# Out:
# ((1686, 63), (1686,))

# %% [markdown]
# ### Spliting the resampled Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=123)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1264, 63), (422, 63), (1264,), (422,))

# %% [markdown]
# ### Scaling the Features

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Building the Algorithms

# %%
clf1 = KNeighborsClassifier()
clf2 = RandomForestClassifier(random_state=1)
clf3 = GaussianNB()
lr = LogisticRegression()
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)

# %%
# Dictionary of different classifiers
clfs = {
'LogisticRegression' : LogisticRegression(),
'DecisionTree': DecisionTreeClassifier(),
'KNNClassifier': KNeighborsClassifier(),
'NaiveBayes': GaussianNB(),
'SupportVectorMachines': SVC(kernel="poly"),
'Bagging': BaggingClassifier(),
'AdaBoostClassifier': AdaBoostClassifier(),
'RandomForestClassifier': RandomForestClassifier(),
'GradientBoostingClassifier': GradientBoostingClassifier(),
'XGBoost': XGBClassifier(),
'StackingClassifier': StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)
}

# %%
# Testing all clfs models and generating a report
models_report = pd.DataFrame(columns = ['Model', 'Accuracy','Precision_score', 'Recall_score','F1_score', 'AUC'])

for clf, clf_name in zip(clfs.values(), clfs.keys()):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    y_score = clf.score(X_test,y_test)
    
    #print('Calculating {}'.format(clf_name))
    t = pd.Series({ 
                     'Model': clf_name,
                     'Precision_score': metrics.precision_score(y_test, y_pred),
                     'Recall_score': metrics.recall_score(y_test, y_pred),
                     'F1_score': metrics.f1_score(y_test, y_pred),
                     'Accuracy': metrics.accuracy_score(y_test, y_pred),
                     'AUC': metrics.roc_auc_score(y_test, y_pred)}
                   )

    models_report = models_report.append(t, ignore_index = True)

models_report
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                          Model  Accuracy  Precision_score  Recall_score  \
# 0           LogisticRegression  0.630332         0.597087      0.627551
# 1                 DecisionTree  0.860190         0.925466      0.760204
# 2                KNNClassifier  0.699052         0.686486      0.647959
# 3                   NaiveBayes  0.509479         0.409836      0.127551
# 4        SupportVectorMachines  0.540284         0.502632      0.974490
# 5                      Bagging  0.872038         0.927711      0.785714
# 6           AdaBoostClassifier  0.767773         0.740196      0.770408
# 7       RandomForestClassifier  0.872038         0.898876      0.816327
# 8   GradientBoostingClassifier  0.864929         0.875676      0.826531
# 9                      XGBoost  0.855450         0.860963      0.821429
# 10          StackingClassifier  0.874408         0.923077      0.795918
#
#     F1_score       AUC
# 0   0.611940  0.630147
# 1   0.834734  0.853553
# 2   0.666667  0.695661
# 3   0.194553  0.484129
# 4   0.663194  0.569103
# 5   0.850829  0.866308
# 6   0.755000  0.767947
# 7   0.855615  0.868340
# 8   0.850394  0.862380
# 9   0.840731  0.853192
# 10  0.854795  0.869198

# %%
# Compared to Part I, generally, there seems to be some improvements for the ensemble methods and not much difference for other
# models
# After tuning the hyperparameters,there are significant improvements across all the models and metrics (see individual
# model performance below) except for logistic regression and naive bayes.
#SVM appears to have experienced the biggest jump in performance using a linear kernel. This may largely be explained by the
# linear relationships between the features and stock return.
# These improvements can also be seen in the roc and lift curves which exhibit significant improvements.
# The farther away the roc curve is from the diagonal or dotted line, the better the model performance
# The farther away the lift curves are from the baseline, the better the model performance

# %% [markdown]
# ## Tuning the hyperparameters using GridSearch/RandomSearch

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier()
rf_params = {'n_estimators': np.arange(50,500,50)}
rf_grid = GridSearchCV(rf, rf_params, cv=5)
rf_grid.fit(X_train, y_train)
y_pred_rf = rf_grid.predict(X_test)
rf_nested_score = cross_val_score(rf_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_rf)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_rf)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_rf)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_rf)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_rf)))
rf_grid.best_params_
# Out:
# Accuracy Score is 0.912322
# Precision Score is 0.907692
# Recall Score is 0.903061
# F1_score is 0.905371
# AUC Score is 0.911708
# {'n_estimators': 250}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(rf_nested_score.mean(), rf_nested_score.std()))
# Out:
# mean of 0.809771 with std. dev. of 0.013725.

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[208  18]
#  [ 19 177]]

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.92      0.92       226
#          1.0       0.91      0.90      0.91       196
#
#    micro avg       0.91      0.91      0.91       422
#    macro avg       0.91      0.91      0.91       422
# weighted avg       0.91      0.91      0.91       422

# %%
rf = RandomForestClassifier(n_estimators=250)
rf = rf.fit(X_train, y_train)
y_probas = rf.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False, figsize=(8,6))

rf = RandomForestClassifier(n_estimators=250)
rf = rf.fit(X_train, y_train)
y_probas = rf.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas, figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
svm = SVC('linear')
svm_params = {'C': [0.1,100,1000], 'gamma':[0.001,0.01,10]}
svm_grid = GridSearchCV(svm, svm_params, cv=5)
#svm_grid = RandomizedSearchCV(svm, param_distributions=svm_params, refit=True, cv=3)
svm_grid.fit(X_train, y_train)
y_pred_svm = svm_grid.predict(X_test)
svm_nested_score = cross_val_score(svm_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_svm)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_svm)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_svm)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_svm)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_svm)))
svm_grid.best_params_
# Out:
# Accuracy Score is 0.940758
# Precision Score is 0.886878
# Recall Score is 1.000000
# F1_score is 0.940048
# AUC Score is 0.944690
# {'C': 100, 'gamma': 10}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(svm_nested_score.mean(), svm_nested_score.std()))
# Out:
# mean of 0.778392 with std. dev. of 0.000502.

# %%
print(confusion_matrix(y_test, y_pred_svm))
# Out:
# [[201  25]
#  [  0 196]]

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94       226
#          1.0       0.89      1.00      0.94       196
#
#    micro avg       0.94      0.94      0.94       422
#    macro avg       0.94      0.94      0.94       422
# weighted avg       0.95      0.94      0.94       422

# %%
svm = SVC(kernel='linear', gamma=10, C=100, probability=True)
svm = svm.fit(X_train, y_train)
y_probas = svm.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

svm = SVC(kernel='linear', gamma=10, C=100, probability=True)
svm = svm.fit(X_train, y_train)
y_probas = svm.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression()
lr_params = {'C': [0.1, 10.0, 100, 1000]}
lr_grid = GridSearchCV(lr, lr_params, cv=5)
lr_grid.fit(X_train, y_train)
y_pred_lr = lr_grid.predict(X_test)
lr_nested_score = cross_val_score(lr_grid, X, y, cv=5)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_lr)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_lr)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_lr)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_lr)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_lr)))
lr_grid.best_params_
# Out:
# Accuracy Score is 0.651659
# Precision Score is 0.618357
# Recall Score is 0.653061
# F1_score is 0.635236
# AUC Score is 0.651752
# {'C': 1000}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(lr_nested_score.mean(), lr_nested_score.std()))
# Out:
# mean of 0.758052 with std. dev. of 0.017549.

# %%
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# [[147  79]
#  [ 68 128]]

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.65      0.67       226
#          1.0       0.62      0.65      0.64       196
#
#    micro avg       0.65      0.65      0.65       422
#    macro avg       0.65      0.65      0.65       422
# weighted avg       0.65      0.65      0.65       422

# %%
lr = LogisticRegression(C=1000)
lr = lr.fit(X_train, y_train)
y_probas = lr.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

lr = LogisticRegression(C=1000)
lr = lr.fit(X_train, y_train)
y_probas = lr.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier()
dt_params = {'max_depth': np.arange(3,12,1),'min_samples_split':np.arange(2,10,1),'min_samples_leaf':np.arange(1,10,1)}
dt_grid = GridSearchCV(dt, dt_params, cv=5)
dt_grid.fit(X_train, y_train)
y_pred_dt = dt_grid.predict(X_test)
dt_nested_score = cross_val_score(dt_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_dt)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_dt)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_dt)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_dt)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_dt)))
dt_grid.best_params_
# Out:
# Accuracy Score is 0.810427
# Precision Score is 0.845238
# Recall Score is 0.724490
# F1_score is 0.780220
# AUC Score is 0.804723
# {'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(dt_nested_score.mean(), dt_nested_score.std()))
# Out:
# mean of 0.790370 with std. dev. of 0.018672.

# %%
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# [[200  26]
#  [ 54 142]]

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       226
#            1       0.85      0.72      0.78       196
#
#    micro avg       0.81      0.81      0.81       422
#    macro avg       0.82      0.80      0.81       422
# weighted avg       0.81      0.81      0.81       422

# %%
dt = DecisionTreeClassifier(max_depth=11, min_samples_leaf=1, min_samples_split=2)
dt = dt.fit(X_train, y_train)
y_probas = dt.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

dt = DecisionTreeClassifier(max_depth=11, min_samples_leaf=1, min_samples_split=2)
dt = dt.fit(X_train, y_train)
y_probas = dt.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### K-Nearest Neigbor (KNN)

# %%
knn = KNeighborsClassifier()
knn_params = {'n_neighbors': np.arange(2,15,1), 'leaf_size':np.arange(3,15,1)}
knn_grid = GridSearchCV(knn, knn_params, cv=5)
knn_grid.fit(X_train, y_train)
y_pred_knn = knn_grid.predict(X_test)
knn_nested_score = cross_val_score(knn_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_knn)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_knn)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_knn)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_knn)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_knn)))
knn_grid.best_params_
# Out:
# Accuracy Score is 0.803318
# Precision Score is 0.952000
# Recall Score is 0.607143
# F1_score is 0.741433
# AUC Score is 0.790297
# {'leaf_size': 3, 'n_neighbors': 2}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(knn_nested_score.mean(), knn_nested_score.std()))
# Out:
# mean of 0.773775 with std. dev. of 0.006561.

# %%
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# [[220   6]
#  [ 77 119]]

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84       226
#            1       0.95      0.61      0.74       196
#
#    micro avg       0.80      0.80      0.80       422
#    macro avg       0.85      0.79      0.79       422
# weighted avg       0.84      0.80      0.79       422

# %%
knn = KNeighborsClassifier(n_neighbors=2, leaf_size=3)
knn = knn.fit(X_train, y_train)
y_probas = knn.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

knn = KNeighborsClassifier(n_neighbors=2, leaf_size=3)
knn = knn.fit(X_train, y_train)
y_probas = knn.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Naive Bayes

# %%
nb = GaussianNB()
nb_params = {'var_smoothing': [1e-12, 1e-11, 1e-10, 1e-09, 1e-08, 1e-07]}
nb_grid = GridSearchCV(nb, nb_params, cv=5)
nb_grid.fit(X_train, y_train)
y_pred_nb = nb_grid.predict(X_test)
nb_nested_score = cross_val_score(nb_grid, X, y, cv=5)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_nb)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_nb)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_nb)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_nb)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_nb)))
nb_grid.best_params_
# Out:
# Accuracy Score is 0.509479
# Precision Score is 0.409836
# Recall Score is 0.127551
# F1_score is 0.194553
# AUC Score is 0.484129
# {'var_smoothing': 1e-12}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(nb_nested_score.mean(), nb_nested_score.std()))
# Out:
# mean of 0.543770 with std. dev. of 0.203500.

# %%
print(confusion_matrix(y_test, y_pred_nb))
# Out:
# [[190  36]
#  [171  25]]

# %%
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.84      0.65       226
#          1.0       0.41      0.13      0.19       196
#
#    micro avg       0.51      0.51      0.51       422
#    macro avg       0.47      0.48      0.42       422
# weighted avg       0.47      0.51      0.44       422

# %%
nb = GaussianNB(var_smoothing=1e-12)
nb = nb.fit(X_train, y_train)
y_probas = nb.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

nb = GaussianNB(var_smoothing=1e-12)
nb = nb.fit(X_train, y_train)
y_probas = nb.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Ada Boost

# %%
ab = AdaBoostClassifier()
ab_params = {'n_estimators': np.arange(50,500,50),'learning_rate':np.arange(0.4,2.0,0.2)}
ab_grid = GridSearchCV(ab, ab_params, cv=3)
ab_grid.fit(X_train, y_train)
y_pred_ab = ab_grid.predict(X_test)
ab_nested_score = cross_val_score(ab_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_ab)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_ab)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_ab)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_ab)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_ab)))
ab_grid.best_params_
# Out:
# Accuracy Score is 0.872038
# Precision Score is 0.898876
# Recall Score is 0.816327
# F1_score is 0.855615
# AUC Score is 0.868340
# {'learning_rate': 0.6000000000000001, 'n_estimators': 450}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(ab_nested_score.mean(), ab_nested_score.std()))
# Out:
# mean of 0.804250 with std. dev. of 0.010306.

# %%
print(confusion_matrix(y_test, y_pred_ab))
# Out:
# [[208  18]
#  [ 36 160]]

# %%
print(classification_report(y_test, y_pred_ab))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.89       226
#          1.0       0.90      0.82      0.86       196
#
#    micro avg       0.87      0.87      0.87       422
#    macro avg       0.88      0.87      0.87       422
# weighted avg       0.87      0.87      0.87       422

# %%
ab = AdaBoostClassifier(learning_rate=0.6, n_estimators=450)
ab = ab.fit(X_train, y_train)
y_probas = ab.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

ab = AdaBoostClassifier(learning_rate=0.6, n_estimators=450)
ab = ab.fit(X_train, y_train)
y_probas = ab.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Gradient Boosting

# %%
gb = GradientBoostingClassifier()
gb_params = {'n_estimators': np.arange(100,500,50),'learning_rate' : np.arange(0.01,0.1,0.02), 'max_depth':np.arange(3,11,2)}
gb_grid = GridSearchCV(gb, gb_params, cv=5)
#gb_grid = RandomizedSearchCV(gb, param_distributions=gb_params, refit=True)
gb_grid.fit(X_train, y_train)
y_pred_gb = gb_grid.predict(X_test)
#gb_nested_score = cross_val_score(gb_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_gb)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_gb)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_gb)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_gb)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_gb)))
gb_grid.best_params_
# Out:
# Accuracy Score is 0.907583
# Precision Score is 0.919786
# Recall Score is 0.877551
# F1_score is 0.898172
# AUC Score is 0.905590
# {'learning_rate': 0.08999999999999998, 'max_depth': 7, 'n_estimators': 150}

# %%
#print("mean of {0:6f} with std. dev. of {1:6f}.".format(gb_nested_score.mean(), gb_nested_score.std()))

# %%
print(confusion_matrix(y_test, y_pred_gb))
# Out:
# [[211  15]
#  [ 24 172]]

# %%
print(classification_report(y_test, y_pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92       226
#          1.0       0.92      0.88      0.90       196
#
#    micro avg       0.91      0.91      0.91       422
#    macro avg       0.91      0.91      0.91       422
# weighted avg       0.91      0.91      0.91       422

# %%
gb = GradientBoostingClassifier(learning_rate=0.08999999999999998, n_estimators=150, max_depth= 7)
gb = gb.fit(X_train, y_train)
y_probas = gb.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

gb = GradientBoostingClassifier(learning_rate=0.08999999999999998, n_estimators=150, max_depth= 7)
gb = gb.fit(X_train, y_train)
y_probas = gb.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Bagging

# %%
bg = BaggingClassifier()
bg_params = {'n_estimators': np.arange(4,20,2)}
bg_grid = GridSearchCV(bg, bg_params, cv=5)
bg_grid.fit(X_train, y_train)
y_pred_bg = bg_grid.predict(X_test)
#bg_nested_score = cross_val_score(bg_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_bg)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_bg)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_bg)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_bg)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_bg)))
bg_grid.best_params_
# Out:
# Accuracy Score is 0.886256
# Precision Score is 0.930233
# Recall Score is 0.816327
# F1_score is 0.869565
# AUC Score is 0.881615
# {'n_estimators': 18}

# %%
#print("mean of {0:6f} with std. dev. of {1:6f}.".format(bg_nested_score.mean(), bg_nested_score.std()))

# %%
print(confusion_matrix(y_test, y_pred_bg))
# Out:
# [[214  12]
#  [ 36 160]]

# %%
print(classification_report(y_test, y_pred_bg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90       226
#          1.0       0.93      0.82      0.87       196
#
#    micro avg       0.89      0.89      0.89       422
#    macro avg       0.89      0.88      0.88       422
# weighted avg       0.89      0.89      0.89       422

# %%
bg = BaggingClassifier(n_estimators=18)
bg = bg.fit(X_train, y_train)
y_probas = bg.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

bg = BaggingClassifier(n_estimators=18)
bg = bg.fit(X_train, y_train)
y_probas = bg.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Stacking Classifier

# %%
clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=450)
clf2 = GradientBoostingClassifier(learning_rate=0.08999999999999998, n_estimators=150, max_depth= 7)
clf3 = BaggingClassifier(n_estimators=18)
rf = RandomForestClassifier(n_estimators=250)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf.fit(X_train, y_train)
y_pred_sclf = bg_grid.predict(X_test)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_sclf)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_sclf)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_sclf)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_sclf)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_sclf)))
# Out:
# Accuracy Score is 0.886256
# Precision Score is 0.930233
# Recall Score is 0.816327
# F1_score is 0.869565
# AUC Score is 0.881615

# %%
print(confusion_matrix(y_test, y_pred_sclf))
# Out:
# [[214  12]
#  [ 36 160]]

# %%
print(classification_report(y_test, y_pred_sclf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90       226
#          1.0       0.93      0.82      0.87       196
#
#    micro avg       0.89      0.89      0.89       422
#    macro avg       0.89      0.88      0.88       422
# weighted avg       0.89      0.89      0.89       422

# %%
clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=450)
clf2 = GradientBoostingClassifier(learning_rate=0.08999999999999998, n_estimators=150, max_depth= 7)
clf3 = BaggingClassifier(n_estimators=14)
rf = RandomForestClassifier(n_estimators=250)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf = sclf.fit(X_train, y_train)
y_probas = sclf.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=450)
clf2 = GradientBoostingClassifier(learning_rate=0.08999999999999998, n_estimators=150, max_depth= 7)
clf3 = BaggingClassifier(n_estimators=14)
rf = RandomForestClassifier(n_estimators=250)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf = sclf.fit(X_train, y_train)
y_probas = sclf.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Artificial Neural Networks (ANN)

# %%
# Importing Keras libraries
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, Bidirectional

# %%
#Initializing the Neural Network
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 216, init = 'uniform', activation = 'relu', input_dim = 63))
#classifier.add(Dense(output_dim = 216, init = 'uniform', activation = 'relu', input_dim = 63))
#classifier.add(Dropout(0.1))
# Adding the second hidden layer
classifier.add(Dense(output_dim = 216, init = 'uniform', activation = 'relu'))
#classifier.add(Dropout(0.1))
classifier.add(Dense(output_dim = 216, init = 'uniform', activation = 'relu'))
# Adding the output layer
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=63, units=216, kernel_initializer="uniform")`
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=216, kernel_initializer="uniform")`
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=216, kernel_initializer="uniform")`
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Compiling the Neural Network
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the Model 
classifier.fit(X_train, y_train, batch_size = 4, nb_epoch = 50)
# Out:
# C:\Anaconda3\lib\site-packages\keras\models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/50
# 1264/1264 [==============================] - 1s - loss: 0.6778 - acc: 0.6123
# Epoch 2/50
# 1264/1264 [==============================] - 0s - loss: 0.6028 - acc: 0.7112
# Epoch 3/50
# 1264/1264 [==============================] - 0s - loss: 0.5341 - acc: 0.7437
# Epoch 4/50
# 1264/1264 [==============================] - 1s - loss: 0.4769 - acc: 0.7745
# Epoch 5/50
# 1264/1264 [==============================] - 0s - loss: 0.3956 - acc: 0.8078
# Epoch 6/50
# 1264/1264 [==============================] - 1s - loss: 0.3488 - acc: 0.8362
# Epoch 7/50
# 1264/1264 [==============================] - 1s - loss: 0.3193 - acc: 0.8671
# Epoch 8/50
# 1264/1264 [==============================] - 1s - loss: 0.2835 - acc: 0.8837     - ETA: 0s - loss:
# Epoch 9/50
# 1264/1264 [==============================] - 1s - loss: 0.2578 - acc: 0.8995
# Epoch 10/50
# 1264/1264 [==============================] - 1s - loss: 0.2361 - acc: 0.9138
# Epoch 11/50
# 1264/1264 [==============================] - 1s - loss: 0.1921 - acc: 0.9351
# Epoch 12/50
# 1264/1264 [==============================] - 1s - loss: 0.1610 - acc: 0.9486
# Epoch 13/50
# 1264/1264 [==============================] - 1s - loss: 0.1251 - acc: 0.9660
# Epoch 14/50
# 1264/1264 [==============================] - 1s - loss: 0.1332 - acc: 0.9509
# Epoch 15/50
# 1264/1264 [==============================] - 1s - loss: 0.1405 - acc: 0.9597
# Epoch 16/50
# 1264/1264 [==============================] - 1s - loss: 0.1082 - acc: 0.9652
# Epoch 17/50
# 1264/1264 [==============================] - 0s - loss: 0.0733 - acc: 0.9786
# Epoch 18/50
# 1264/1264 [==============================] - 1s - loss: 0.0751 - acc: 0.9786
# Epoch 19/50
# 1264/1264 [==============================] - 1s - loss: 0.0909 - acc: 0.9826
# Epoch 20/50
# 1264/1264 [==============================] - 1s - loss: 0.0355 - acc: 0.9929
# Epoch 21/50
# 1264/1264 [==============================] - 1s - loss: 0.0757 - acc: 0.9778
# Epoch 22/50
# 1264/1264 [==============================] - 1s - loss: 0.0618 - acc: 0.9897
# Epoch 23/50
# 1264/1264 [==============================] - 1s - loss: 0.0823 - acc: 0.9842
# Epoch 24/50
# 1264/1264 [==============================] - 1s - loss: 0.0833 - acc: 0.9842
# Epoch 25/50
# 1264/1264 [==============================] - 1s - loss: 0.0942 - acc: 0.9802
# Epoch 26/50
# 1264/1264 [==============================] - 1s - loss: 0.0736 - acc: 0.9834
# Epoch 27/50
# 1264/1264 [==============================] - 1s - loss: 0.0319 - acc: 0.9913
# Epoch 28/50
# 1264/1264 [==============================] - 1s - loss: 0.0427 - acc: 0.9873
# Epoch 29/50
# 1264/1264 [==============================] - 1s - loss: 0.0800 - acc: 0.9826
# Epoch 30/50
# 1264/1264 [==============================] - 1s - loss: 0.0270 - acc: 0.9945
# Epoch 31/50
# 1264/1264 [==============================] - 1s - loss: 0.0188 - acc: 0.9976
# Epoch 32/50
# 1264/1264 [==============================] - 1s - loss: 0.0163 - acc: 0.9976
# Epoch 33/50
# 1264/1264 [==============================] - 1s - loss: 0.1696 - acc: 0.9557
# Epoch 34/50
# 1264/1264 [==============================] - 1s - loss: 0.0681 - acc: 0.9881
# Epoch 35/50
# 1264/1264 [==============================] - 1s - loss: 0.0433 - acc: 0.9921
# Epoch 36/50
# 1264/1264 [==============================] - 1s - loss: 0.0355 - acc: 0.9953
# Epoch 37/50
# 1264/1264 [==============================] - 1s - loss: 0.0294 - acc: 0.9968
# Epoch 38/50
# 1264/1264 [==============================] - 1s - loss: 0.0274 - acc: 0.9968
# Epoch 39/50
# 1264/1264 [==============================] - 1s - loss: 0.0299 - acc: 0.9960
# Epoch 40/50
# 1264/1264 [==============================] - 1s - loss: 0.1261 - acc: 0.9778
# Epoch 41/50
# 1264/1264 [==============================] - 1s - loss: 0.0683 - acc: 0.9858
# Epoch 42/50
# 1264/1264 [==============================] - 1s - loss: 0.0744 - acc: 0.9802
# Epoch 43/50
# 1264/1264 [==============================] - 1s - loss: 0.0475 - acc: 0.9921
# Epoch 44/50
# 1264/1264 [==============================] - 1s - loss: 0.0300 - acc: 0.9968
# Epoch 45/50
# 1264/1264 [==============================] - 1s - loss: 0.0758 - acc: 0.9810
# Epoch 46/50
# 1264/1264 [==============================] - 1s - loss: 0.0631 - acc: 0.9842
# Epoch 47/50
# 1264/1264 [==============================] - 1s - loss: 0.0366 - acc: 0.9937
# Epoch 48/50
# 1264/1264 [==============================] - 1s - loss: 0.0284 - acc: 0.9976
# Epoch 49/50
# 1264/1264 [==============================] - 1s - loss: 0.0277 - acc: 0.9960
# Epoch 50/50
# 1264/1264 [==============================] - 1s - loss: 0.0270 - acc: 0.9976

# %%
# Predicting the Test set
y_pred_nn = classifier.predict(X_test)
y_pred_nn = (y_pred_nn > 0.5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_nn)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_nn)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_nn)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_nn)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_nn)))
# Out:
# Accuracy Score is 0.876777
# Precision Score is 0.913793
# Recall Score is 0.811224
# F1_score is 0.859459
# AUC Score is 0.872426

# %%
# The Confusion Matrix
print(confusion_matrix(y_test, y_pred_nn))
# Out:
# [[211  15]
#  [ 37 159]]

# %%
print(classification_report(y_test, y_pred_nn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89       226
#          1.0       0.91      0.81      0.86       196
#
#    micro avg       0.88      0.88      0.88       422
#    macro avg       0.88      0.87      0.87       422
# weighted avg       0.88      0.88      0.88       422

# %% [markdown]
# ## Feature Selection using Step Forward Feature Selection

# %%
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# %%
# Build RF classifier to use in feature selection
clf = BaggingClassifier(n_estimators=20)

# Build step forward feature selection
sfs1 = sfs(clf,
           k_features=20,
           forward=True, # Otherwise, this will be the backward selection 
           floating=False,
           n_jobs=10, # The number of CPUs to use for evaluating 
           verbose=2,
           scoring='accuracy',
           cv=3)

# Perform SFFS
sfs1 = sfs1.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=10)]: Done  63 out of  63 | elapsed:   21.9s finished
#
# [2019-01-01 22:29:21] Features: 1/20 -- score: 0.8243699691566991[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=10)]: Done  62 out of  62 | elapsed:    3.7s finished
#
# [2019-01-01 22:29:25] Features: 2/20 -- score: 0.8528661701647483[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=10)]: Done  61 out of  61 | elapsed:    4.1s finished
#
# [2019-01-01 22:29:29] Features: 3/20 -- score: 0.8718310388926502[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=10)]: Done  60 out of  60 | elapsed:    4.7s finished
#
# [2019-01-01 22:29:34] Features: 4/20 -- score: 0.8765854208982171[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=10)]: Done  59 out of  59 | elapsed:    5.4s finished
#
# [2019-01-01 22:29:39] Features: 5/20 -- score: 0.8821484992101106[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=10)]: Done  58 out of  58 | elapsed:    5.6s finished
#
# [2019-01-01 22:29:45] Features: 6/20 -- score: 0.8860904235311818[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=10)]: Done  57 out of  57 | elapsed:    6.9s finished
#
# [2019-01-01 22:29:52] Features: 7/20 -- score: 0.8884525690212893[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=10)]: Done  56 out of  56 | elapsed:    7.0s finished
#
# [2019-01-01 22:29:59] Features: 8/20 -- score: 0.885296772737531[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=10)]: Done  55 out of  55 | elapsed:    7.3s finished
#
# [2019-01-01 22:30:07] Features: 9/20 -- score: 0.8884525690212893[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=10)]: Done  54 out of  54 | elapsed:    7.4s finished
#
# [2019-01-01 22:30:14] Features: 10/20 -- score: 0.8868915970811706[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=10)]: Done  53 out of  53 | elapsed:    7.8s finished
#
# [2019-01-01 22:30:22] Features: 11/20 -- score: 0.8884488076431204[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=10)]: Done  52 out of  52 | elapsed:    8.5s finished
#
# [2019-01-01 22:30:31] Features: 12/20 -- score: 0.8829346272474234[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=10)]: Done  51 out of  51 | elapsed:    8.9s finished
#
# [2019-01-01 22:30:40] Features: 13/20 -- score: 0.8916008425487099[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=10)]: Done  50 out of  50 | elapsed:    9.1s finished
#
# [2019-01-01 22:30:49] Features: 14/20 -- score: 0.8924095388550365[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=10)]: Done  49 out of  49 | elapsed:    9.3s finished
#
# [2019-01-01 22:30:58] Features: 15/20 -- score: 0.8900173023395772[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=10)]: Done  48 out of  48 | elapsed:    9.6s finished
#
# [2019-01-01 22:31:08] Features: 16/20 -- score: 0.8892349356804333[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=10)]: Done  47 out of  47 | elapsed:    9.6s finished
#
# [2019-01-01 22:31:18] Features: 17/20 -- score: 0.8939855563078312[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=10)]: Done  46 out of  46 | elapsed:   10.8s finished
#
# [2019-01-01 22:31:29] Features: 18/20 -- score: 0.8947641615888061[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=10)]: Done  45 out of  45 | elapsed:   10.9s finished
#
# [2019-01-01 22:31:39] Features: 19/20 -- score: 0.8963665086887835[Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=10)]: Done  44 out of  44 | elapsed:   10.3s finished
#
# [2019-01-01 22:31:50] Features: 20/20 -- score: 0.8908259986459038

# %%
# Candidate features?
feat_cols = list(sfs1.k_feature_idx_)
print(feat_cols)
# Out:
# [0, 3, 4, 6, 7, 8, 9, 10, 11, 14, 16, 21, 31, 33, 34, 35, 37, 39, 56, 57]

# %%
sfs1.subsets_
# Out:
# {1: {'feature_idx': (57,),
#   'cv_scores': array([0.84123223, 0.8056872 , 0.82619048]),
#   'avg_score': 0.8243699691566991,
#   'feature_names': ('57',)},
#  2: {'feature_idx': (11, 57),
#   'cv_scores': array([0.83412322, 0.86018957, 0.86428571]),
#   'avg_score': 0.8528661701647483,
#   'feature_names': ('11', '57')},
#  3: {'feature_idx': (10, 11, 57),
#   'cv_scores': array([0.87203791, 0.87440758, 0.86904762]),
#   'avg_score': 0.8718310388926502,
#   'feature_names': ('10', '11', '57')},
#  4: {'feature_idx': (10, 11, 16, 57),
#   'cv_scores': array([0.87203791, 0.87914692, 0.87857143]),
#   'avg_score': 0.8765854208982171,
#   'feature_names': ('10', '11', '16', '57')},
#  5: {'feature_idx': (10, 11, 16, 34, 57),
#   'cv_scores': array([0.86018957, 0.88625592, 0.9       ]),
#   'avg_score': 0.8821484992101106,
#   'feature_names': ('10', '11', '16', '34', '57')},
#  6: {'feature_idx': (10, 11, 16, 34, 37, 57),
#   'cv_scores': array([0.87203791, 0.89099526, 0.8952381 ]),
#   'avg_score': 0.8860904235311818,
#   'feature_names': ('10', '11', '16', '34', '37', '57')},
#  7: {'feature_idx': (4, 10, 11, 16, 34, 37, 57),
#   'cv_scores': array([0.87677725, 0.89810427, 0.89047619]),
#   'avg_score': 0.8884525690212893,
#   'feature_names': ('4', '10', '11', '16', '34', '37', '57')},
#  8: {'feature_idx': (4, 10, 11, 16, 34, 35, 37, 57),
#   'cv_scores': array([0.87677725, 0.88625592, 0.89285714]),
#   'avg_score': 0.885296772737531,
#   'feature_names': ('4', '10', '11', '16', '34', '35', '37', '57')},
#  9: {'feature_idx': (4, 10, 11, 16, 33, 34, 35, 37, 57),
#   'cv_scores': array([0.88862559, 0.88625592, 0.89047619]),
#   'avg_score': 0.8884525690212893,
#   'feature_names': ('4', '10', '11', '16', '33', '34', '35', '37', '57')},
#  10: {'feature_idx': (0, 4, 10, 11, 16, 33, 34, 35, 37, 57),
#   'cv_scores': array([0.86966825, 0.88862559, 0.90238095]),
#   'avg_score': 0.8868915970811706,
#   'feature_names': ('0', '4', '10', '11', '16', '33', '34', '35', '37', '57')},
#  11: {'feature_idx': (0, 4, 10, 11, 16, 33, 34, 35, 37, 39, 57),
#   'cv_scores': array([0.90521327, 0.87203791, 0.88809524]),
#   'avg_score': 0.8884488076431204,
#   'feature_names': ('0',
#    '4',
#    '10',
#    '11',
#    '16',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '57')},
#  12: {'feature_idx': (0, 4, 7, 10, 11, 16, 33, 34, 35, 37, 39, 57),
#   'cv_scores': array([0.86492891, 0.88625592, 0.89761905]),
#   'avg_score': 0.8829346272474234,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '10',
#    '11',
#    '16',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '57')},
#  13: {'feature_idx': (0, 4, 7, 8, 10, 11, 16, 33, 34, 35, 37, 39, 57),
#   'cv_scores': array([0.9028436 , 0.88862559, 0.88333333]),
#   'avg_score': 0.8916008425487099,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '8',
#    '10',
#    '11',
#    '16',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '57')},
#  14: {'feature_idx': (0, 4, 7, 8, 10, 11, 14, 16, 33, 34, 35, 37, 39, 57),
#   'cv_scores': array([0.90758294, 0.87440758, 0.8952381 ]),
#   'avg_score': 0.8924095388550365,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '8',
#    '10',
#    '11',
#    '14',
#    '16',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '57')},
#  15: {'feature_idx': (0, 4, 7, 8, 10, 11, 14, 16, 31, 33, 34, 35, 37, 39, 57),
#   'cv_scores': array([0.8957346 , 0.89336493, 0.88095238]),
#   'avg_score': 0.8900173023395772,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '8',
#    '10',
#    '11',
#    '14',
#    '16',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '57')},
#  16: {'feature_idx': (0,
#    4,
#    7,
#    8,
#    10,
#    11,
#    14,
#    16,
#    31,
#    33,
#    34,
#    35,
#    37,
#    39,
#    56,
#    57),
#   'cv_scores': array([0.89099526, 0.89099526, 0.88571429]),
#   'avg_score': 0.8892349356804333,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '8',
#    '10',
#    '11',
#    '14',
#    '16',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '56',
#    '57')},
#  17: {'feature_idx': (0,
#    4,
#    7,
#    8,
#    9,
#    10,
#    11,
#    14,
#    16,
#    31,
#    33,
#    34,
#    35,
#    37,
#    39,
#    56,
#    57),
#   'cv_scores': array([0.90995261, 0.87914692, 0.89285714]),
#   'avg_score': 0.8939855563078312,
#   'feature_names': ('0',
#    '4',
#    '7',
#    '8',
#    '9',
#    '10',
#    '11',
#    '14',
#    '16',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '56',
#    '57')},
#  18: {'feature_idx': (0,
#    4,
#    6,
#    7,
#    8,
#    9,
#    10,
#    11,
#    14,
#    16,
#    31,
#    33,
#    34,
#    35,
#    37,
#    39,
#    56,
#    57),
#   'cv_scores': array([0.91706161, 0.88151659, 0.88571429]),
#   'avg_score': 0.8947641615888061,
#   'feature_names': ('0',
#    '4',
#    '6',
#    '7',
#    '8',
#    '9',
#    '10',
#    '11',
#    '14',
#    '16',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '56',
#    '57')},
#  19: {'feature_idx': (0,
#    3,
#    4,
#    6,
#    7,
#    8,
#    9,
#    10,
#    11,
#    14,
#    16,
#    31,
#    33,
#    34,
#    35,
#    37,
#    39,
#    56,
#    57),
#   'cv_scores': array([0.91706161, 0.87203791, 0.9       ]),
#   'avg_score': 0.8963665086887835,
#   'feature_names': ('0',
#    '3',
#    '4',
#    '6',
#    '7',
#    '8',
#    '9',
#    '10',
#    '11',
#    '14',
#    '16',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '56',
#    '57')},
#  20: {'feature_idx': (0,
#    3,
#    4,
#    6,
#    7,
#    8,
#    9,
#    10,
#    11,
#    14,
#    16,
#    21,
#    31,
#    33,
#    34,
#    35,
#    37,
#    39,
#    56,
#    57),
#   'cv_scores': array([0.90047393, 0.87914692, 0.89285714]),
#   'avg_score': 0.8908259986459038,
#   'feature_names': ('0',
#    '3',
#    '4',
#    '6',
#    '7',
#    '8',
#    '9',
#    '10',
#    '11',
#    '14',
#    '16',
#    '21',
#    '31',
#    '33',
#    '34',
#    '35',
#    '37',
#    '39',
#    '56',
#    '57')}}

# %% [markdown]
# ### Plotting the results

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt

# %%
sfs = sfs(clf, 
          k_features=63, 
          forward=True, 
          floating=False, 
          scoring='accuracy',
          verbose=2,
          cv=3)

sfs = sfs.fit(X_train, y_train)

fig1 = plot_sfs(sfs.get_metric_dict(), kind='std_dev')

plt.ylim([0.8, 1])
plt.title('Sequential Forward Selection (w. StdDev)')
plt.grid()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    7.6s finished
#
# [2019-01-01 22:31:58] Features: 1/63 -- score: 0.8275332881967953[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    7.7s finished
#
# [2019-01-01 22:32:06] Features: 2/63 -- score: 0.8536334913112165[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:    8.9s finished
#
# [2019-01-01 22:32:15] Features: 3/63 -- score: 0.8631234484315052[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   10.8s finished
#
# [2019-01-01 22:32:26] Features: 4/63 -- score: 0.8686865267433989[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:   10.3s finished
#
# [2019-01-01 22:32:36] Features: 5/63 -- score: 0.8726134055517942[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:   12.9s finished
#
# [2019-01-01 22:32:49] Features: 6/63 -- score: 0.8734145791017829[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:   12.5s finished
#
# [2019-01-01 22:33:02] Features: 7/63 -- score: 0.8829346272474234[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:   13.2s finished
#
# [2019-01-01 22:33:15] Features: 8/63 -- score: 0.8781576769728429[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:   14.3s finished
#
# [2019-01-01 22:33:30] Features: 9/63 -- score: 0.8805386293537952[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:   15.6s finished
#
# [2019-01-01 22:33:45] Features: 10/63 -- score: 0.8805047769502746[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:   15.3s finished
#
# [2019-01-01 22:34:01] Features: 11/63 -- score: 0.8844730309185286[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:   16.6s finished
#
# [2019-01-01 22:34:17] Features: 12/63 -- score: 0.8821259309410968[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:   17.2s finished
#
# [2019-01-01 22:34:35] Features: 13/63 -- score: 0.8844918378093732[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   17.6s finished
#
# [2019-01-01 22:34:52] Features: 14/63 -- score: 0.8907921462423832[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:   18.0s finished
#
# [2019-01-01 22:35:10] Features: 15/63 -- score: 0.8884488076431204[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:   18.6s finished
#
# [2019-01-01 22:35:29] Features: 16/63 -- score: 0.8939742721733243[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:   19.4s finished
#
# [2019-01-01 22:35:49] Features: 17/63 -- score: 0.889249981193109[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:   21.2s finished
#
# [2019-01-01 22:36:10] Features: 18/63 -- score: 0.8892161287895886[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   21.0s finished
#
# [2019-01-01 22:36:31] Features: 19/63 -- score: 0.8900135409614083[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:   23.5s finished
#
# [2019-01-01 22:36:55] Features: 20/63 -- score: 0.8868577446776499[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:   24.2s finished
#
# [2019-01-01 22:37:19] Features: 21/63 -- score: 0.8971375912134206[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:   23.6s finished
#
# [2019-01-01 22:37:43] Features: 22/63 -- score: 0.8908259986459038[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:   24.7s finished
#
# [2019-01-01 22:38:07] Features: 23/63 -- score: 0.8915820356578651[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   23.8s finished
#
# [2019-01-01 22:38:31] Features: 24/63 -- score: 0.8923869705860227[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:   23.4s finished
#
# [2019-01-01 22:38:55] Features: 25/63 -- score: 0.8923869705860227[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:   23.8s finished
#
# [2019-01-01 22:39:19] Features: 26/63 -- score: 0.9011208906943504[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:   26.9s finished
#
# [2019-01-01 22:39:46] Features: 27/63 -- score: 0.8979199578725646[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:   25.5s finished
#
# [2019-01-01 22:40:11] Features: 28/63 -- score: 0.8955427668697812[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:   25.0s finished
#
# [2019-01-01 22:40:36] Features: 29/63 -- score: 0.9018919732189875[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:   30.1s finished
#
# [2019-01-01 22:41:07] Features: 30/63 -- score: 0.8971451139697585[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:   32.8s finished
#
# [2019-01-01 22:41:39] Features: 31/63 -- score: 0.890810953133228[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:   28.6s finished
#
# [2019-01-01 22:42:08] Features: 32/63 -- score: 0.898743699691567[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   26.7s finished
#
# [2019-01-01 22:42:35] Features: 33/63 -- score: 0.8955615737606258[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   26.7s finished
#
# [2019-01-01 22:43:02] Features: 34/63 -- score: 0.8971338298352517[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   23.4s finished
#
# [2019-01-01 22:43:25] Features: 35/63 -- score: 0.8955314827352742[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   24.0s finished
#
# [2019-01-01 22:43:49] Features: 36/63 -- score: 0.8979086737380576[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   24.3s finished
#
# [2019-01-01 22:44:14] Features: 37/63 -- score: 0.9018656435718047[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   23.6s finished
#
# [2019-01-01 22:44:38] Features: 38/63 -- score: 0.894767922966975[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   22.7s finished
#
# [2019-01-01 22:45:00] Features: 39/63 -- score: 0.8892086060332506[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   21.6s finished
#
# [2019-01-01 22:45:22] Features: 40/63 -- score: 0.8923869705860227[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   21.6s finished
#
# [2019-01-01 22:45:44] Features: 41/63 -- score: 0.8947829684796509[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   22.1s finished
#
# [2019-01-01 22:46:06] Features: 42/63 -- score: 0.8939855563078312[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   21.2s finished
#
# [2019-01-01 22:46:27] Features: 43/63 -- score: 0.8916046039268788[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   20.0s finished
#
# [2019-01-01 22:46:47] Features: 44/63 -- score: 0.8923756864515159[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   19.6s finished
#
# [2019-01-01 22:47:07] Features: 45/63 -- score: 0.8900060182050703[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   19.9s finished
#
# [2019-01-01 22:47:27] Features: 46/63 -- score: 0.8876363499586248[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   19.5s finished
#
# [2019-01-01 22:47:47] Features: 47/63 -- score: 0.8971263070789138[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   18.5s finished
#
# [2019-01-01 22:48:05] Features: 48/63 -- score: 0.8907846234860454[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   17.0s finished
#
# [2019-01-01 22:48:22] Features: 49/63 -- score: 0.8916158880613857[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   16.5s finished
#
# [2019-01-01 22:48:39] Features: 50/63 -- score: 0.892368163695178[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   15.5s finished
#
# [2019-01-01 22:48:54] Features: 51/63 -- score: 0.8931994282705182[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   14.5s finished
#
# [2019-01-01 22:49:09] Features: 52/63 -- score: 0.8900173023395772[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   13.6s finished
#
# [2019-01-01 22:49:23] Features: 53/63 -- score: 0.8931881441360114[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   13.7s finished
#
# [2019-01-01 22:49:36] Features: 54/63 -- score: 0.8963514631761077[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   11.2s finished
#
# [2019-01-01 22:49:48] Features: 55/63 -- score: 0.8892086060332506[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   10.1s finished
#
# [2019-01-01 22:49:58] Features: 56/63 -- score: 0.8955352441134431[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    9.1s finished
#
# [2019-01-01 22:50:07] Features: 57/63 -- score: 0.8891973218987438[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.2s finished
#
# [2019-01-01 22:50:15] Features: 58/63 -- score: 0.8891973218987438[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.8s finished
#
# [2019-01-01 22:50:22] Features: 59/63 -- score: 0.886842699164974[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.7s finished
#
# [2019-01-01 22:50:29] Features: 60/63 -- score: 0.8939592266606485[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.9s finished
#
# [2019-01-01 22:50:35] Features: 61/63 -- score: 0.889249981193109[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s finished
#
# [2019-01-01 22:50:39] Features: 62/63 -- score: 0.8892198901677575[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s finished
#
# [2019-01-01 22:50:41] Features: 63/63 -- score: 0.878135108703829

# %%
# From the plot above, 20 features are able to explain much of the performance in the dependent variable (stock return)

# %% [markdown]
# ### Building the Model with Selected Features only

# %%
clf =  BaggingClassifier(n_estimators=18)
clf.fit(X_train[:, feat_cols], y_train)

y_train_pred = clf.predict(X_train[:, feat_cols])
print('Training accuracy on selected features: %.3f' % acc(y_train, y_train_pred))

y_test_pred = clf.predict(X_test[:, feat_cols])
print('Testing accuracy on selected features: %.3f' % acc(y_test, y_test_pred))
# Out:
# Training accuracy on selected features: 1.000
# Testing accuracy on selected features: 0.903

# %% [markdown]
# ### Building the Model with ALL features for comparison

# %%
clf = BaggingClassifier(n_estimators=18)
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
print('Training accuracy on all features: %.3f' % acc(y_train, y_train_pred))

y_test_pred = clf.predict(X_test)
print('Testing accuracy on all features: %.3f' % acc(y_test, y_test_pred))
# Out:
# Training accuracy on all features: 0.996
# Testing accuracy on all features: 0.884

# %%
# Building the model with the top 20 features lead to an accuracy of 90% which is much better than using all features
# This implies that most of the features are redundant

# %% [markdown]
# ### Feature Selection with Random Forest

# %%
rf = RandomForestClassifier(n_estimators=250)
#rf_params = {'n_estimators': np.arange(50,500,50)}
#rf_grid = RandomizedSearchCV(rf, param_distributions=rf_params, refit=True)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(rf.feature_importances_)
# Out:
# [0.01277735 0.01310824 0.01316836 0.01143077 0.01303021 0.00820379
#  0.01188991 0.01153184 0.01096407 0.01025811 0.01030001 0.01195813
#  0.01106634 0.01119094 0.02546697 0.01428104 0.01829074 0.01302938
#  0.01296448 0.01310708 0.00757563 0.01195535 0.01204711 0.01284451
#  0.013638   0.01487295 0.00624161 0.0143266  0.01246608 0.01270829
#  0.01064877 0.01246447 0.01257208 0.01195634 0.01132613 0.01312867
#  0.01436507 0.0163624  0.017877   0.01181969 0.01268018 0.01228717
#  0.01324701 0.01769264 0.01192678 0.01144326 0.01288853 0.01345146
#  0.01870438 0.01414699 0.01696153 0.0230457  0.04045014 0.03780511
#  0.01940877 0.01328813 0.01701225 0.03643226 0.02616881 0.01838509
#  0.05850778 0.03694336 0.00790818]

# %%
# Selecting Features from the dataset to feed into the model
dataset.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1       21st Century Fox    FOX                     0.0545
# 2        3D SYSTEMS CORP    DDD                     0.0779
# 3                     3M    MMM                     0.0585
# 4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)  ...   \
# 0                -0.2443                  -0.1610  ...
# 1                -0.0141                  -0.0073  ...
# 2                -0.0525                   0.1345  ...
# 3                -0.0454                  -0.0502  ...
# 4                 2.5943                  12.4883  ...
#
#    MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0              720.839700            879.482310            12.00
# 1            84236.546737         104151.607755            14.77
# 2             2045.077054           1313.512819            69.11
# 3           123317.884925         125106.677466            15.41
# 4             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)  \
# 0            0.72         20.29       0.37         0.0449               5.0
# 1            3.41         20.51       0.24         0.0620               6.0
# 2            1.92        -24.24       0.42        -0.0319               0.0
# 3            3.81         24.34       0.09         0.0532               4.0
# 4            6.02        -14.09       0.14        -0.0359               1.0
#
#      Return  Loss
# 0  0.107477   0.0
# 1  0.401115   0.0
# 2  0.140251   0.0
# 3 -0.190989   1.0
# 4  0.263860   0.0
#
# [5 rows x 67 columns]

# %%
dataset.columns.get_loc('P. F-Score (TTM)')
# Out:
# 64

# %%
dataset1 = dataset.iloc[:,2:65]

# %%
dataset1.shape
# Out:
# (1083, 63)

# %%
#Extract feature names from the data
feat = dataset1.keys()
feat_labels = feat.get_values()

# %%
feature = pd.DataFrame({'Feature':feat_labels, 'Feature importance':rf.feature_importances_})
feature = feature.sort_values(by='Feature importance', ascending=False)
feature
# Out:
#                                Feature  Feature importance
# 60                           Book/MCAP            0.058508
# 52                           P/S (TTM)            0.040450
# 53                           P/B (TTM)            0.037805
# 61                       EBIT/EV (TTM)            0.036943
# 57                     EV/EBITDA (TTM)            0.036432
# 58                      EV/Sales (TTM)            0.026169
# 14       Cash and eq. (%chg., TTM, 1y)            0.025467
# 51                           P/E (TTM)            0.023046
# 54                         P/FCF (TTM)            0.019409
# 48                 Book/Sh. (TTM, USD)            0.018704
# 59                        EV/FCF (TTM)            0.018385
# 16        Cur. assets (%chg., TTM, 1y)            0.018291
# 38              Operating Margin (TTM)            0.017877
# 43                    Liab./Equ. (TTM)            0.017693
# 56                EV (in million, USD)            0.017012
# 50                 Div./Sh. (TTM, USD)            0.016962
# 37                    Net Margin (TTM)            0.016362
# 25     Eq. excl. min. (%chg., TTM, 1y)            0.014873
# 36                FCF (%chg., TTM, 1y)            0.014365
# 27             Equity (%chg., TTM, 1y)            0.014327
# 15        Receivables (%chg., TTM, 1y)            0.014281
# 49                  FCF/Sh. (TTM, USD)            0.014147
# 24        Liabilities (%chg., TTM, 1y)            0.013638
# 47                Sales/Sh. (TTM, USD)            0.013451
# 55              MCAP (in million, USD)            0.013288
# 42                 Current ratio (TTM)            0.013247
# 2        Gross Profit (%chg., TTM, 1y)            0.013168
# 35          Cash chg. (%chg., TTM, 1y)            0.013129
# 1                COGS (%chg., TTM, 1y)            0.013108
# 19       Acc. payable (%chg., TTM, 1y)            0.013107
# ..                                 ...                 ...
# 46                 dil. EPS (TTM, USD)            0.012889
# 23               Debt (%chg., TTM, 1y)            0.012845
# 0            Revenues (%chg., TTM, 1y)            0.012777
# 29            Chg. WC (%chg., TTM, 1y)            0.012708
# 40                           ROA (TTM)            0.012680
# 32            Inv. CF (%chg., TTM, 1y)            0.012572
# 28                D&A (%chg., TTM, 1y)            0.012466
# 31       Chg. in PP&E (%chg., TTM, 1y)            0.012464
# 41                  FCF/Net inc. (TTM)            0.012287
# 22            LT debt (%chg., TTM, 1y)            0.012047
# 11              Taxes (%chg., TTM, 1y)            0.011958
# 33          Dividends (%chg., TTM, 1y)            0.011956
# 21         Cur. liab. (%chg., TTM, 1y)            0.011955
# 44                   Debt/Assets (TTM)            0.011927
# 6                EBIT (%chg., TTM, 1y)            0.011890
# 39                           ROE (TTM)            0.011820
# 7              EBITDA (%chg., TTM, 1y)            0.011532
# 45                basic EPS (TTM, USD)            0.011443
# 3            Op. Exp. (%chg., TTM, 1y)            0.011431
# 34            Fin. CF (%chg., TTM, 1y)            0.011326
# 13         Net income (%chg., TTM, 1y)            0.011191
# 12   Income cont. op. (%chg., TTM, 1y)            0.011066
# 8       Interest, net (%chg., TTM, 1y)            0.010964
# 30             Op. CF (%chg., TTM, 1y)            0.010649
# 10        Pretax Inc. (%chg., TTM, 1y)            0.010300
# 9   Pretax Inc. (adj) (%chg., TTM, 1y)            0.010258
# 5                 R&D (%chg., TTM, 1y)            0.008204
# 62                    P. F-Score (TTM)            0.007908
# 20            ST debt (%chg., TTM, 1y)            0.007576
# 26         Minorities (%chg., TTM, 1y)            0.006242
#
# [63 rows x 2 columns]

# %% [markdown]
# ## Features Importance Analysis

# %% [markdown]
# ### General Observations

# %%
# From the table above, certain features are more important than others in explaining stock return.
# Some of the top five (5) variables are:
# 1 Book/MCAP(Market Capitalization)
# 2 Price/Sales
# 3 Price/Book Value
# 4 EBIT/EV (Enterprise Value)
# 5 EV/EBITDA
# Not surprising, most of the top features from the table above have been proven in finance research to drive stock return 
# for the medium and long term.

# %%
#for feature in zip(feat_labels, rf.feature_importances_):
   # print(feature)

# %% [markdown]
# ### What is the direction of correlation of these attributes with the level of return?

# %%
# Subsetting the Top 20 Attributes for Correlation

# %%
#corrdata = dataset1.iloc[:,[60,52,53,61,57,58,14,51,54,48,59,16,38,43,56,50,37,25,36,27]]
#corrdata.head()

# %%
corrdata = dataset[['Book/MCAP','P/S (TTM)','P/B (TTM)','EBIT/EV (TTM)','EV/EBITDA (TTM)','EV/Sales (TTM)', \
                    'Cash and eq. (%chg., TTM, 1y)','P/E (TTM)','P/FCF (TTM)','Book/Sh. (TTM, USD)','EV/FCF (TTM)', \
                    'Cur. assets (%chg., TTM, 1y)','Operating Margin (TTM)','Liab./Equ. (TTM)','EV (in million, USD)', \
                    'Div./Sh. (TTM, USD)','Net Margin (TTM)','Eq. excl. min. (%chg., TTM, 1y)','FCF (%chg., TTM, 1y)', \
                    'Equity (%chg., TTM, 1y)','Return']]

# %%
corrdata.head()
# Out:
#    Book/MCAP  P/S (TTM)  P/B (TTM)  EBIT/EV (TTM)  EV/EBITDA (TTM)  \
# 0       0.37       0.66       2.72         0.0449            12.00
# 1       0.24       2.97       4.14         0.0620            14.77
# 2       0.42       2.00       2.33        -0.0319            69.11
# 3       0.09       3.53      11.22         0.0532            15.41
# 4       0.14       6.35       6.76        -0.0359           -42.78
#
#    EV/Sales (TTM)  Cash and eq. (%chg., TTM, 1y)  P/E (TTM)  P/FCF (TTM)  \
# 0            0.72                         1.9561      20.83        18.52
# 1            3.41                         0.0264      18.54        17.87
# 2            1.92                        -0.3343     -26.52       -25.20
# 3            3.81                         0.0310      25.57        22.51
# 4            6.02                        -0.2283     -11.86       -14.88
#
#    Book/Sh. (TTM, USD)    ...     Cur. assets (%chg., TTM, 1y)  \
# 0                 4.58    ...                           0.1100
# 1                11.17    ...                           0.1253
# 2                 5.18    ...                          -0.0217
# 3                17.30    ...                           0.0559
# 4                 2.58    ...                          -0.0973
#
#    Operating Margin (TTM)  Liab./Equ. (TTM)  EV (in million, USD)  \
# 0                  0.0324            0.8265            879.482310
# 1                  0.2111            1.4864         104151.607755
# 2                 -0.0612            0.3814           1313.512819
# 3                  0.2027            2.6151         125106.677466
# 4                 -0.2160            0.2936           1532.456973
#
#    Div./Sh. (TTM, USD)  Net Margin (TTM)  Eq. excl. min. (%chg., TTM, 1y)  \
# 0                 0.00            0.0316                           0.1136
# 1                 0.55            0.1698                           0.2695
# 2                 0.00           -0.0749                          -0.0602
# 3                 5.24            0.1383                          -0.1563
# 4                 0.00           -0.5357                          -0.2202
#
#    FCF (%chg., TTM, 1y)  Equity (%chg., TTM, 1y)    Return
# 0                0.0814                   0.1136  0.107477
# 1                0.3107                   0.2488  0.401115
# 2                0.8056                  -0.0585  0.140251
# 3                0.0124                  -0.1550 -0.190989
# 4               37.2062                  -0.2202  0.263860
#
# [5 rows x 21 columns]

# %%
plt.rcParams['figure.figsize']=(18,10)
plt.style.use('ggplot')
cormat = corrdata.corr()
sns.heatmap(cormat, square=True);

# %% [markdown]
# ## Disclaimer

# %%
# The content of this publication is intended for information and education purposes only. It is very important that you do 
# your own analysis before making any investment decision based on your own personal circumstances. You should take independent
# financial advice from a professional in connection with, or independently research and verify, any information you find in
# this publication and wish to rely upon, whether for the purpose of making investment decision or otherwise.
