# %% [markdown]
# ## Stock Return Prediction using Fundamental Data Part I

# %% [markdown]
# ### Introduction

# %%
# This projects seeks to uncover key fundamental ratios and variables that significantly drive stock returns for the
# medium and long term.
# Please note this is not a trading strategy
# Datsets were downloaded in piecemeal, four different datasets (fundamental stock data ) downloaded from simfin.com 
# [simfin](https://simfin.com/) Whereas return data were scraped from yahoo finance

 # Part II of this project utilizes a couple of classical techniques to solve the problem of imbalanced datasets

# %% [markdown]
# ## Part I Using An Imbalanced Dataset

# %% [markdown]
# ## Data Preprocessing Part A

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import pandasql as ps
from pandasql import sqldf
import matplotlib.pyplot as plt
# %matplotlib inline
from functools import reduce
import seaborn as sns

# %%
data3 = pd.read_excel('SimFin-data3.xlsx', skiprows=3)
data2 = pd.read_excel('SimFin-data2.xlsx', skiprows=3)
data1 = pd.read_excel('SimFin-data1.xlsx', skiprows=3)
data = pd.read_excel('SimFin-data.xlsx', skiprows=3)

# %%
data3.head()
# Out:
#    Unnamed: 0                          Unnamed: 1  Net Margin (TTM)  \
# 0         NaN       Red Giant Entertainment, Inc.          331.5819
# 1         NaN                           BRK, Inc.          131.2954
# 2         NaN                   GI DYNAMICS, INC.           68.8000
# 3         NaN  Advanced Emissions Solutions, Inc.            4.7649
# 4         NaN       Biostar Pharmaceuticals, Inc.            2.9401
#
#    Operating Margin (TTM)  ROE (TTM)  ROA (TTM)  FCF/Net inc. (TTM)  \
# 0                 47.8588        NaN        NaN                 NaN
# 1               -241.4679    -0.6633    80.3244                 NaN
# 2                 64.4000     2.1191    -2.3745              0.9284
# 3                 -1.8799     0.4452     0.4262             -1.0949
# 4                -16.6802     0.0258     0.0226              1.2778
#
#    Current ratio (TTM)  Liab./Equ. (TTM)  Debt/Assets (TTM)        ...         \
# 0                  NaN               NaN                NaN        ...
# 1               0.0082           -1.0083            54.7184        ...
# 2               0.4673           -1.8925             1.4613        ...
# 3              12.1173            0.0446             0.0000        ...
# 4               0.1888            0.1461             0.0586        ...
#
#    P/B (TTM) P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0        NaN         NaN                0.000000                   NaN
# 1      -4.20         NaN                4.823608              5.253946
# 2      -0.06       -0.03                0.246662              2.283662
# 3       2.74       -5.62              239.940252                   NaN
# 4       0.09        2.63                3.164626              5.226751
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0              NaN             NaN           NaN        NaN            NaN
# 1              NaN         1072.02           NaN      -0.20        -0.2252
# 2            -0.30          -19.03         -0.30     -12.70        -3.3840
# 3              NaN             NaN           NaN        NaN            NaN
# 4            -1.25           16.45          4.38      11.42        -1.0142
#
#    P. F-Score (TTM)
# 0               NaN
# 1               NaN
# 2               2.0
# 3               NaN
# 4               4.0
#
# [5 rows x 29 columns]

# %%
data3a = data3.drop(data3.columns[[0,1]],axis=1) #Dropping columns not needed (duplication)

# %%
data3a.head()
# Out:
#    Net Margin (TTM)  Operating Margin (TTM)  ROE (TTM)  ROA (TTM)  \
# 0          331.5819                 47.8588        NaN        NaN
# 1          131.2954               -241.4679    -0.6633    80.3244
# 2           68.8000                 64.4000     2.1191    -2.3745
# 3            4.7649                 -1.8799     0.4452     0.4262
# 4            2.9401                -16.6802     0.0258     0.0226
#
#    FCF/Net inc. (TTM)  Current ratio (TTM)  Liab./Equ. (TTM)  \
# 0                 NaN                  NaN               NaN
# 1                 NaN               0.0082           -1.0083
# 2              0.9284               0.4673           -1.8925
# 3             -1.0949              12.1173            0.0446
# 4              1.2778               0.1888            0.1461
#
#    Debt/Assets (TTM)  basic EPS (TTM, USD) Ticker        ...         \
# 0                NaN                   NaN   REDG        ...
# 1            54.7184                  0.01    BRK        ...
# 2             1.4613                 -0.69  GIDYL        ...
# 3             0.0000                  1.75   ADES        ...
# 4             0.0586                  0.36   BSPM        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0        NaN          NaN                0.000000                   NaN
# 1      -4.20          NaN                4.823608              5.253946
# 2      -0.06        -0.03                0.246662              2.283662
# 3       2.74        -5.62              239.940252                   NaN
# 4       0.09         2.63                3.164626              5.226751
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0              NaN             NaN           NaN        NaN            NaN
# 1              NaN         1072.02           NaN      -0.20        -0.2252
# 2            -0.30          -19.03         -0.30     -12.70        -3.3840
# 3              NaN             NaN           NaN        NaN            NaN
# 4            -1.25           16.45          4.38      11.42        -1.0142
#
#    P. F-Score (TTM)
# 0               NaN
# 1               NaN
# 2               2.0
# 3               NaN
# 4               4.0
#
# [5 rows x 27 columns]

# %%
data2.head()
# Out:
#    Unnamed: 0             Unnamed: 1 Ticker  Revenues (%chg., TTM, 1y)  \
# 0         NaN  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1         NaN        1ST SOURCE CORP   SRCE                     0.1083
# 2         NaN       21st Century Fox    FOX                     0.0545
# 3         NaN        3D SYSTEMS CORP    DDD                     0.0779
# 4         NaN                     3M    MMM                     0.0585
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                    NaN                            NaN
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                        NaN                    NaN                   NaN
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)  \
# 0                -0.2443                  -0.1610
# 1                -0.0008                  -0.0039
# 2                -0.0141                  -0.0073
# 3                -0.0525                   0.1345
# 4                -0.0454                  -0.0502
#
#    Interest, net (%chg., TTM, 1y)  Pretax Inc. (adj) (%chg., TTM, 1y)  \
# 0                         -0.3353                             -0.4219
# 1                             NaN                             -0.0008
# 2                          0.0025                             -0.0566
# 3                          9.1778                             -0.0058
# 4                          2.9634                             -0.0812
#
#    Pretax Inc. (%chg., TTM, 1y)  Taxes (%chg., TTM, 1y)  \
# 0                       -0.4219                 -1.1511
# 1                       -0.0008                 -0.3847
# 2                       -0.0312                 -1.4288
# 3                       -0.0058                  0.2559
# 4                       -0.0713                  0.2150
#
#    Income cont. op. (%chg., TTM, 1y)  Net income (%chg., TTM, 1y)  \
# 0                            -0.2113                      -0.2113
# 1                             0.2096                       0.2096
# 2                             0.5939                       0.6390
# 3                             0.0236                       0.0133
# 4                            -0.1747                      -0.1758
#
#    Cash and eq. (%chg., TTM, 1y)  Receivables (%chg., TTM, 1y)  \
# 0                         1.9561                       -0.1393
# 1                         0.0576                           NaN
# 2                         0.0264                           NaN
# 3                        -0.3343                        0.0382
# 4                         0.0310                        0.0336
#
#    Cur. assets (%chg., TTM, 1y)
# 0                        0.1100
# 1                           NaN
# 2                        0.1253
# 3                       -0.0217
# 4                        0.0559

# %%
data2a = data2.drop(data2.columns[[0]],axis=1)

# %%
data2a.head()
# Out:
#               Unnamed: 1 Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1        1ST SOURCE CORP   SRCE                     0.1083
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                    NaN                            NaN
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                        NaN                    NaN                   NaN
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)  \
# 0                -0.2443                  -0.1610
# 1                -0.0008                  -0.0039
# 2                -0.0141                  -0.0073
# 3                -0.0525                   0.1345
# 4                -0.0454                  -0.0502
#
#    Interest, net (%chg., TTM, 1y)  Pretax Inc. (adj) (%chg., TTM, 1y)  \
# 0                         -0.3353                             -0.4219
# 1                             NaN                             -0.0008
# 2                          0.0025                             -0.0566
# 3                          9.1778                             -0.0058
# 4                          2.9634                             -0.0812
#
#    Pretax Inc. (%chg., TTM, 1y)  Taxes (%chg., TTM, 1y)  \
# 0                       -0.4219                 -1.1511
# 1                       -0.0008                 -0.3847
# 2                       -0.0312                 -1.4288
# 3                       -0.0058                  0.2559
# 4                       -0.0713                  0.2150
#
#    Income cont. op. (%chg., TTM, 1y)  Net income (%chg., TTM, 1y)  \
# 0                            -0.2113                      -0.2113
# 1                             0.2096                       0.2096
# 2                             0.5939                       0.6390
# 3                             0.0236                       0.0133
# 4                            -0.1747                      -0.1758
#
#    Cash and eq. (%chg., TTM, 1y)  Receivables (%chg., TTM, 1y)  \
# 0                         1.9561                       -0.1393
# 1                         0.0576                           NaN
# 2                         0.0264                           NaN
# 3                        -0.3343                        0.0382
# 4                         0.0310                        0.0336
#
#    Cur. assets (%chg., TTM, 1y)
# 0                        0.1100
# 1                           NaN
# 2                        0.1253
# 3                       -0.0217
# 4                        0.0559

# %%
data1.head()
# Out:
#    Unnamed: 0                    Unnamed: 1 Ticker  PPE (%chg., TTM, 1y)  \
# 0         NaN      AGILENT TECHNOLOGIES INC      A                0.1187
# 1         NaN                    Alcoa Corp     AA               -0.0999
# 2         NaN  American Airlines Group Inc.    AAL                   NaN
# 3         NaN   Altisource Residential Corp   AAMC                0.4154
# 4         NaN        ATLANTIC AMERICAN CORP   AAME                   NaN
#
#    Assets (%chg., TTM, 1y)  Acc. payable (%chg., TTM, 1y)  \
# 0                   0.0107                        -0.0554
# 1                  -0.0620                         0.0575
# 2                      NaN                            NaN
# 3                   0.2465                            NaN
# 4                   0.0157                            NaN
#
#    ST debt (%chg., TTM, 1y)  Cur. liab. (%chg., TTM, 1y)  \
# 0                   -1.0000                      -0.1829
# 1                   -0.7647                       0.0860
# 2                       NaN                          NaN
# 3                    0.5425                       0.5331
# 4                       NaN                          NaN
#
#    LT debt (%chg., TTM, 1y)  Debt (%chg., TTM, 1y)  \
# 0                   -0.0011                -0.1355
# 1                    0.3150                 0.3019
# 2                       NaN                -1.0000
# 3                       NaN                 0.5425
# 4                       NaN                    NaN
#
#    Liabilities (%chg., TTM, 1y)  Pref. Equity (%chg., TTM, 1y)  \
# 0                        0.0359                            NaN
# 1                       -0.0258                            NaN
# 2                           NaN                            NaN
# 3                        0.5331                            NaN
# 4                        0.0579                            0.0
#
#    Common Stock (%chg., TTM, 1y)  Eq. excl. min. (%chg., TTM, 1y)  \
# 0                            0.0                          -0.0095
# 1                            0.0                          -0.1102
# 2                            NaN                              NaN
# 3                            NaN                          -0.2374
# 4                            NaN                          -0.0703
#
#    Minorities (%chg., TTM, 1y)  Equity (%chg., TTM, 1y)  D&A (%chg., TTM, 1y)  \
# 0                       0.3333                  -0.0093               -0.0463
# 1                      -0.0829                  -0.1026                0.0013
# 2                          NaN                      NaN                0.1095
# 3                          NaN                  -0.2374                   NaN
# 4                          NaN                  -0.0703               -0.2825
#
#    Chg. WC (%chg., TTM, 1y)  Op. CF (%chg., TTM, 1y)  Price (USD)
# 0                   -0.3216                   0.2012        62.67
# 1                    1.3402                  -0.6349        25.15
# 2                   -2.6142                  -0.3431        29.72
# 3                       NaN                      NaN        33.00
# 4                    0.5428                  -1.5584         2.37

# %%
data1a = data1.drop(data1.columns[[0,1]],axis=1)

# %%
data1a.head()
# Out:
#   Ticker  PPE (%chg., TTM, 1y)  Assets (%chg., TTM, 1y)  \
# 0      A                0.1187                   0.0107
# 1     AA               -0.0999                  -0.0620
# 2    AAL                   NaN                      NaN
# 3   AAMC                0.4154                   0.2465
# 4   AAME                   NaN                   0.0157
#
#    Acc. payable (%chg., TTM, 1y)  ST debt (%chg., TTM, 1y)  \
# 0                        -0.0554                   -1.0000
# 1                         0.0575                   -0.7647
# 2                            NaN                       NaN
# 3                            NaN                    0.5425
# 4                            NaN                       NaN
#
#    Cur. liab. (%chg., TTM, 1y)  LT debt (%chg., TTM, 1y)  \
# 0                      -0.1829                   -0.0011
# 1                       0.0860                    0.3150
# 2                          NaN                       NaN
# 3                       0.5331                       NaN
# 4                          NaN                       NaN
#
#    Debt (%chg., TTM, 1y)  Liabilities (%chg., TTM, 1y)  \
# 0                -0.1355                        0.0359
# 1                 0.3019                       -0.0258
# 2                -1.0000                           NaN
# 3                 0.5425                        0.5331
# 4                    NaN                        0.0579
#
#    Pref. Equity (%chg., TTM, 1y)  Common Stock (%chg., TTM, 1y)  \
# 0                            NaN                            0.0
# 1                            NaN                            0.0
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            0.0                            NaN
#
#    Eq. excl. min. (%chg., TTM, 1y)  Minorities (%chg., TTM, 1y)  \
# 0                          -0.0095                       0.3333
# 1                          -0.1102                      -0.0829
# 2                              NaN                          NaN
# 3                          -0.2374                          NaN
# 4                          -0.0703                          NaN
#
#    Equity (%chg., TTM, 1y)  D&A (%chg., TTM, 1y)  Chg. WC (%chg., TTM, 1y)  \
# 0                  -0.0093               -0.0463                   -0.3216
# 1                  -0.1026                0.0013                    1.3402
# 2                      NaN                0.1095                   -2.6142
# 3                  -0.2374                   NaN                       NaN
# 4                  -0.0703               -0.2825                    0.5428
#
#    Op. CF (%chg., TTM, 1y)  Price (USD)
# 0                   0.2012        62.67
# 1                  -0.6349        25.15
# 2                  -0.3431        29.72
# 3                      NaN        33.00
# 4                  -1.5584         2.37

# %%
data.head()
# Out:
#    Unnamed: 0             Unnamed: 1 Ticker  Chg. in PP&E (%chg., TTM, 1y)  \
# 0         NaN  1 800 FLOWERS COM INC   FLWS                         0.0362
# 1         NaN        1ST SOURCE CORP   SRCE                        -1.9157
# 2         NaN       21st Century Fox    FOX                         0.4074
# 3         NaN        3D SYSTEMS CORP    DDD                         0.4929
# 4         NaN                     3M    MMM                         0.0302
#
#    Inv. CF (%chg., TTM, 1y)  Dividends (%chg., TTM, 1y)  \
# 0                   -1.4850                         NaN
# 1                    0.3018                      0.2232
# 2                    2.7432                      0.0669
# 3                   -0.4225                         NaN
# 4                    2.5856                      0.1217
#
#    Fin. CF (%chg., TTM, 1y)  Cash chg. (%chg., TTM, 1y)  FCF (%chg., TTM, 1y)
# 0                   -0.8647                      6.4987                0.0814
# 1                    0.5474                      3.0144                0.1875
# 2                    1.2244                     -0.9180                0.3107
# 3                    0.0485                      0.1162                0.8056
# 4                   -0.3679                     -0.3231                0.0124

# %%
dataa = data.drop(data.columns[[0,1]],axis=1)

# %%
dataa.head()
# Out:
#   Ticker  Chg. in PP&E (%chg., TTM, 1y)  Inv. CF (%chg., TTM, 1y)  \
# 0   FLWS                         0.0362                   -1.4850
# 1   SRCE                        -1.9157                    0.3018
# 2    FOX                         0.4074                    2.7432
# 3    DDD                         0.4929                   -0.4225
# 4    MMM                         0.0302                    2.5856
#
#    Dividends (%chg., TTM, 1y)  Fin. CF (%chg., TTM, 1y)  \
# 0                         NaN                   -0.8647
# 1                      0.2232                    0.5474
# 2                      0.0669                    1.2244
# 3                         NaN                    0.0485
# 4                      0.1217                   -0.3679
#
#    Cash chg. (%chg., TTM, 1y)  FCF (%chg., TTM, 1y)
# 0                      6.4987                0.0814
# 1                      3.0144                0.1875
# 2                     -0.9180                0.3107
# 3                      0.1162                0.8056
# 4                     -0.3231                0.0124

# %%
data3a.shape, data2a.shape, data1a.shape, dataa.shape
# Out:
# ((2134, 27), (2134, 19), (2136, 18), (2134, 7))

# %%
data1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2136 entries, 0 to 2135
# Data columns (total 18 columns):
# Ticker                             2132 non-null object
# PPE (%chg., TTM, 1y)               1816 non-null float64
# Assets (%chg., TTM, 1y)            1968 non-null float64
# Acc. payable (%chg., TTM, 1y)      1702 non-null float64
# ST debt (%chg., TTM, 1y)           1252 non-null float64
# Cur. liab. (%chg., TTM, 1y)        1857 non-null float64
# LT debt (%chg., TTM, 1y)           1500 non-null float64
# Debt (%chg., TTM, 1y)              1615 non-null float64
# Liabilities (%chg., TTM, 1y)       1970 non-null float64
# Pref. Equity (%chg., TTM, 1y)      178 non-null float64
# Common Stock (%chg., TTM, 1y)      239 non-null float64
# Eq. excl. min. (%chg., TTM, 1y)    1952 non-null float64
# Minorities (%chg., TTM, 1y)        677 non-null float64
# Equity (%chg., TTM, 1y)            1970 non-null float64
# D&A (%chg., TTM, 1y)               1764 non-null float64
# Chg. WC (%chg., TTM, 1y)           1808 non-null float64
# Op. CF (%chg., TTM, 1y)            1819 non-null float64
# Price (USD)                        2048 non-null float64
# dtypes: float64(17), object(1)
# memory usage: 300.5+ KB

# %%
#Combining all four datasets
combdata = reduce(lambda x,y: pd.merge(x,y, on='Ticker', how='outer'), [data2a,data1a,dataa, data3a])

# %%
combdata.shape
# Out:
# (2514, 68)

# %%
combdata.head()
# Out:
#               Unnamed: 1 Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1        1ST SOURCE CORP   SRCE                     0.1083
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                    NaN                            NaN
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                        NaN                    NaN                   NaN
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 1                -0.0008                  -0.0039        ...
# 2                -0.0141                  -0.0073        ...
# 3                -0.0525                   0.1345        ...
# 4                -0.0454                  -0.0502        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 1       1.59       -48.23                     NaN           1542.297797
# 2       4.14        17.87            84236.546737         104151.607755
# 3       2.33       -25.20             2045.077054           1313.512819
# 4      11.22        22.51           123317.884925         125106.677466
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 1            14.35            5.05        -62.53       0.63         0.0655
# 2            14.77            3.41         20.51       0.24         0.0620
# 3            69.11            1.92        -24.24       0.42        -0.0319
# 4            15.41            3.81         24.34       0.09         0.0532
#
#    P. F-Score (TTM)
# 0               5.0
# 1               NaN
# 2               6.0
# 3               NaN
# 4               4.0
#
# [5 rows x 68 columns]

# %%
combdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2514 entries, 0 to 2513
# Data columns (total 68 columns):
# Unnamed: 1                            2513 non-null object
# Ticker                                2482 non-null object
# Revenues (%chg., TTM, 1y)             2067 non-null float64
# COGS (%chg., TTM, 1y)                 1835 non-null float64
# Gross Profit (%chg., TTM, 1y)         1954 non-null float64
# Op. Exp. (%chg., TTM, 1y)             2013 non-null float64
# SG&A (%chg., TTM, 1y)                 1906 non-null float64
# R&D (%chg., TTM, 1y)                  846 non-null float64
# EBIT (%chg., TTM, 1y)                 2131 non-null float64
# EBITDA (%chg., TTM, 1y)               1968 non-null float64
# Interest, net (%chg., TTM, 1y)        1796 non-null float64
# Pretax Inc. (adj) (%chg., TTM, 1y)    2131 non-null float64
# Pretax Inc. (%chg., TTM, 1y)          2131 non-null float64
# Taxes (%chg., TTM, 1y)                1960 non-null float64
# Income cont. op. (%chg., TTM, 1y)     2131 non-null float64
# Net income (%chg., TTM, 1y)           2130 non-null float64
# Cash and eq. (%chg., TTM, 1y)         2307 non-null float64
# Receivables (%chg., TTM, 1y)          1756 non-null float64
# Cur. assets (%chg., TTM, 1y)          2191 non-null float64
# PPE (%chg., TTM, 1y)                  2145 non-null float64
# Assets (%chg., TTM, 1y)               2311 non-null float64
# Acc. payable (%chg., TTM, 1y)         2017 non-null float64
# ST debt (%chg., TTM, 1y)              1532 non-null float64
# Cur. liab. (%chg., TTM, 1y)           2186 non-null float64
# LT debt (%chg., TTM, 1y)              1808 non-null float64
# Debt (%chg., TTM, 1y)                 1937 non-null float64
# Liabilities (%chg., TTM, 1y)          2313 non-null float64
# Pref. Equity (%chg., TTM, 1y)         227 non-null float64
# Common Stock (%chg., TTM, 1y)         288 non-null float64
# Eq. excl. min. (%chg., TTM, 1y)       2288 non-null float64
# Minorities (%chg., TTM, 1y)           922 non-null float64
# Equity (%chg., TTM, 1y)               2313 non-null float64
# D&A (%chg., TTM, 1y)                  2044 non-null float64
# Chg. WC (%chg., TTM, 1y)              2088 non-null float64
# Op. CF (%chg., TTM, 1y)               2099 non-null float64
# Price (USD)                           2412 non-null float64
# Chg. in PP&E (%chg., TTM, 1y)         2021 non-null float64
# Inv. CF (%chg., TTM, 1y)              2092 non-null float64
# Dividends (%chg., TTM, 1y)            1106 non-null float64
# Fin. CF (%chg., TTM, 1y)              2106 non-null float64
# Cash chg. (%chg., TTM, 1y)            2110 non-null float64
# FCF (%chg., TTM, 1y)                  1967 non-null float64
# Net Margin (TTM)                      2128 non-null float64
# Operating Margin (TTM)                2128 non-null float64
# ROE (TTM)                             2074 non-null float64
# ROA (TTM)                             2074 non-null float64
# FCF/Net inc. (TTM)                    2000 non-null float64
# Current ratio (TTM)                   2241 non-null float64
# Liab./Equ. (TTM)                      2367 non-null float64
# Debt/Assets (TTM)                     2367 non-null float64
# basic EPS (TTM, USD)                  1976 non-null float64
# dil. EPS (TTM, USD)                   1947 non-null float64
# Sales/Sh. (TTM, USD)                  1976 non-null float64
# Book/Sh. (TTM, USD)                   2161 non-null float64
# FCF/Sh. (TTM, USD)                    1870 non-null float64
# Div./Sh. (TTM, USD)                   1975 non-null float64
# P/E (TTM)                             1934 non-null float64
# P/S (TTM)                             1934 non-null float64
# P/B (TTM)                             2113 non-null float64
# P/FCF (TTM)                           1834 non-null float64
# MCAP (in million, USD)                2223 non-null float64
# EV (in million, USD)                  2163 non-null float64
# EV/EBITDA (TTM)                       1836 non-null float64
# EV/Sales (TTM)                        1921 non-null float64
# EV/FCF (TTM)                          1836 non-null float64
# Book/MCAP                             2163 non-null float64
# EBIT/EV (TTM)                         1921 non-null float64
# P. F-Score (TTM)                      1520 non-null float64
# dtypes: float64(66), object(2)
# memory usage: 1.3+ MB

# %%
#Checking for null values
combdata.isna().values.any()
# Out:
# True

# %%
combdata.describe()
# Out:
#        Revenues (%chg., TTM, 1y)  COGS (%chg., TTM, 1y)  \
# count                2067.000000            1835.000000
# mean                    0.524691               0.140997
# std                    11.601300               0.741525
# min                    -6.366800              -4.223200
# 25%                     0.014950               0.007950
# 50%                     0.076900               0.077100
# 75%                     0.180450               0.178650
# max                   428.452400              17.550500
#
#        Gross Profit (%chg., TTM, 1y)  Op. Exp. (%chg., TTM, 1y)  \
# count                    1954.000000                2013.000000
# mean                        0.452479                   0.241994
# std                         9.850886                   9.594514
# min                       -10.366600                -141.542100
# 25%                         0.003825                  -0.003000
# 50%                         0.077950                   0.072600
# 75%                         0.203100                   0.182700
# max                       428.452400                 406.170700
#
#        SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  EBIT (%chg., TTM, 1y)  \
# count            1906.000000            846.000000            2131.000000
# mean               34.402351              0.199723               0.355575
# std              1488.554885              1.757616               9.860011
# min               -30.987100             -2.842100             -66.567100
# 25%                -0.006475             -0.024100              -0.208700
# 50%                 0.076150              0.097950               0.043500
# 75%                 0.179025              0.236175               0.245700
# max             64986.000000             48.274400             358.170600
#
#        EBITDA (%chg., TTM, 1y)  Interest, net (%chg., TTM, 1y)  \
# count              1968.000000                     1796.000000
# mean                  0.578106                        0.965356
# std                  20.047080                       19.336017
# min                -114.173900                     -183.365100
# 25%                  -0.104025                       -0.080125
# 50%                   0.068600                        0.058300
# 75%                   0.243100                        0.301325
# max                 868.958900                      567.000000
#
#        Pretax Inc. (adj) (%chg., TTM, 1y)        ...            P/B (TTM)  \
# count                          2131.00000        ...          2113.000000
# mean                             -0.08889        ...            -4.075092
# std                              17.34752        ...           440.799879
# min                            -741.60000        ...        -12901.460000
# 25%                              -0.24370        ...             1.140000
# 50%                               0.03880        ...             2.120000
# 75%                               0.28415        ...             4.310000
# max                             149.71010        ...         14317.190000
#
#         P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# count   1834.000000            2.223000e+03          2.163000e+03
# mean       5.669128            2.307923e+04          2.675814e+04
# std      978.950764            8.308036e+04          8.347284e+04
# min   -24243.180000            0.000000e+00         -2.624200e+04
# 25%       -0.270000            5.434159e+02          5.703333e+02
# 50%       11.015000            3.770800e+03          4.819276e+03
# 75%       24.280000            1.493937e+04          1.734758e+04
# max    25587.210000            1.083304e+06          1.004807e+06
#
#        EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)     Book/MCAP  \
# count      1836.000000     1921.000000   1836.000000  2.163000e+03
# mean       -101.909003       15.867616      8.120387  5.842576e+03
# std        5275.279984      296.693605   1196.374012  2.694509e+05
# min     -224333.560000      -19.030000 -23461.190000 -3.722923e+04
# 25%           5.717500        0.950000     -0.055000  1.600000e-01
# 50%          11.135000        2.280000     13.740000  3.700000e-01
# 75%          16.430000        4.730000     28.765000  7.100000e-01
# max       21358.020000    12336.000000  41289.940000  1.253150e+07
#
#        EBIT/EV (TTM)  P. F-Score (TTM)
# count    1921.000000       1520.000000
# mean        0.063799          5.017105
# std         5.512343          1.833338
# min      -114.870500          0.000000
# 25%         0.012700          4.000000
# 50%         0.047700          5.000000
# 75%         0.073900          6.000000
# max       208.192400          9.000000
#
# [8 rows x 66 columns]

# %%
combdata.head()
# Out:
#               Unnamed: 1 Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1        1ST SOURCE CORP   SRCE                     0.1083
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                    NaN                            NaN
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                        NaN                    NaN                   NaN
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 1                -0.0008                  -0.0039        ...
# 2                -0.0141                  -0.0073        ...
# 3                -0.0525                   0.1345        ...
# 4                -0.0454                  -0.0502        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 1       1.59       -48.23                     NaN           1542.297797
# 2       4.14        17.87            84236.546737         104151.607755
# 3       2.33       -25.20             2045.077054           1313.512819
# 4      11.22        22.51           123317.884925         125106.677466
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 1            14.35            5.05        -62.53       0.63         0.0655
# 2            14.77            3.41         20.51       0.24         0.0620
# 3            69.11            1.92        -24.24       0.42        -0.0319
# 4            15.41            3.81         24.34       0.09         0.0532
#
#    P. F-Score (TTM)
# 0               5.0
# 1               NaN
# 2               6.0
# 3               NaN
# 4               4.0
#
# [5 rows x 68 columns]

# %%
# renaming the first column
combdata = combdata.rename(columns={combdata.columns[0]: "Name"})

# %%
combdata.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1        1ST SOURCE CORP   SRCE                     0.1083
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                    NaN                            NaN
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                        NaN                    NaN                   NaN
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 1                -0.0008                  -0.0039        ...
# 2                -0.0141                  -0.0073        ...
# 3                -0.0525                   0.1345        ...
# 4                -0.0454                  -0.0502        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 1       1.59       -48.23                     NaN           1542.297797
# 2       4.14        17.87            84236.546737         104151.607755
# 3       2.33       -25.20             2045.077054           1313.512819
# 4      11.22        22.51           123317.884925         125106.677466
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 1            14.35            5.05        -62.53       0.63         0.0655
# 2            14.77            3.41         20.51       0.24         0.0620
# 3            69.11            1.92        -24.24       0.42        -0.0319
# 4            15.41            3.81         24.34       0.09         0.0532
#
#    P. F-Score (TTM)
# 0               5.0
# 1               NaN
# 2               6.0
# 3               NaN
# 4               4.0
#
# [5 rows x 68 columns]

# %%
# locating the Price column to drop later
combdata.columns.get_loc("Price (USD)")
# Out:
# 35

# %%
#combdata.head(n=1500)

# %%
#combdata.isnull().sum()

# %%
# drop rows with Null values for Revenue, COGS and Op.Exp
combdata1 = combdata.dropna(subset=["Revenues (%chg., TTM, 1y)","COGS (%chg., TTM, 1y)", \
                                    "Op. Exp. (%chg., TTM, 1y)"])

# %%
combdata.shape, combdata1.shape
# Out:
# ((2514, 68), (1830, 68))

# %%
#combdata1.head(n=1500)

# %%
# drop rows with null values for EV/EBITDA
combdata2 = combdata1.dropna(subset=["EV/EBITDA (TTM)"])

# %%
combdata2.shape
# Out:
# (1565, 68)

# %%
combdata2.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
# 6           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
# 6                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 2                     0.0238                 0.0164                   NaN
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
# 6                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 2                -0.0141                  -0.0073        ...
# 3                -0.0525                   0.1345        ...
# 4                -0.0454                  -0.0502        ...
# 6                 2.5943                  12.4883        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 2       4.14        17.87            84236.546737         104151.607755
# 3       2.33       -25.20             2045.077054           1313.512819
# 4      11.22        22.51           123317.884925         125106.677466
# 6       6.76       -14.88             1816.977159           1532.456973
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 2            14.77            3.41         20.51       0.24         0.0620
# 3            69.11            1.92        -24.24       0.42        -0.0319
# 4            15.41            3.81         24.34       0.09         0.0532
# 6           -42.78            6.02        -14.09       0.14        -0.0359
#
#    P. F-Score (TTM)
# 0               5.0
# 2               6.0
# 3               NaN
# 4               4.0
# 6               1.0
#
# [5 rows x 68 columns]

# %%
combdata2.isnull().sum(axis=0)
# Out:
# Name                                     0
# Ticker                                  16
# Revenues (%chg., TTM, 1y)                0
# COGS (%chg., TTM, 1y)                    0
# Gross Profit (%chg., TTM, 1y)            0
# Op. Exp. (%chg., TTM, 1y)                0
# SG&A (%chg., TTM, 1y)                   61
# R&D (%chg., TTM, 1y)                   885
# EBIT (%chg., TTM, 1y)                    0
# EBITDA (%chg., TTM, 1y)                 17
# Interest, net (%chg., TTM, 1y)         171
# Pretax Inc. (adj) (%chg., TTM, 1y)       0
# Pretax Inc. (%chg., TTM, 1y)             0
# Taxes (%chg., TTM, 1y)                  62
# Income cont. op. (%chg., TTM, 1y)        0
# Net income (%chg., TTM, 1y)              0
# Cash and eq. (%chg., TTM, 1y)            7
# Receivables (%chg., TTM, 1y)           224
# Cur. assets (%chg., TTM, 1y)             3
# PPE (%chg., TTM, 1y)                    22
# Assets (%chg., TTM, 1y)                 11
# Acc. payable (%chg., TTM, 1y)           94
# ST debt (%chg., TTM, 1y)               494
# Cur. liab. (%chg., TTM, 1y)             16
# LT debt (%chg., TTM, 1y)               285
# Debt (%chg., TTM, 1y)                  251
# Liabilities (%chg., TTM, 1y)            11
# Pref. Equity (%chg., TTM, 1y)         1464
# Common Stock (%chg., TTM, 1y)         1364
# Eq. excl. min. (%chg., TTM, 1y)         25
#                                       ...
# Dividends (%chg., TTM, 1y)             759
# Fin. CF (%chg., TTM, 1y)                27
# Cash chg. (%chg., TTM, 1y)              20
# FCF (%chg., TTM, 1y)                    31
# Net Margin (TTM)                        19
# Operating Margin (TTM)                  19
# ROE (TTM)                               10
# ROA (TTM)                               10
# FCF/Net inc. (TTM)                       6
# Current ratio (TTM)                     13
# Liab./Equ. (TTM)                         9
# Debt/Assets (TTM)                        9
# basic EPS (TTM, USD)                    98
# dil. EPS (TTM, USD)                    112
# Sales/Sh. (TTM, USD)                    98
# Book/Sh. (TTM, USD)                     90
# FCF/Sh. (TTM, USD)                      85
# Div./Sh. (TTM, USD)                     92
# P/E (TTM)                               99
# P/S (TTM)                               99
# P/B (TTM)                               90
# P/FCF (TTM)                             85
# MCAP (in million, USD)                  66
# EV (in million, USD)                    10
# EV/EBITDA (TTM)                          0
# EV/Sales (TTM)                          10
# EV/FCF (TTM)                             0
# Book/MCAP                               10
# EBIT/EV (TTM)                           10
# P. F-Score (TTM)                       260
# Length: 68, dtype: int64

# %%
#Change in common and preference shares are mostly NaN because firms do not issue shares every yearly, so remove the columns.
#Also remove rows with no ticker symbols

# %%
combdata2a = combdata2.dropna(subset=["Ticker"]) # Drop columns with no ticker symbols

# %%
#combdata2a.isnull().sum()

# %%
combdata2a.columns.get_loc("Pref. Equity (%chg., TTM, 1y)")
# Out:
# 27

# %%
combdata2.columns.get_loc("Common Stock (%chg., TTM, 1y)")
# Out:
# 28

# %%
# Drop the price column to be replaced later with annual price return as the dependent variable
combdata2.columns.get_loc("Price (USD)")
# Out:
# 35

# %%
combdata3 = combdata2a.drop(combdata2.columns[[27,28, 35]], axis=1)

# %%
combdata2a.shape, combdata3.shape
# Out:
# ((1549, 68), (1549, 65))

# %%
combdata3.isnull().sum()
# Out:
# Name                                    0
# Ticker                                  0
# Revenues (%chg., TTM, 1y)               0
# COGS (%chg., TTM, 1y)                   0
# Gross Profit (%chg., TTM, 1y)           0
# Op. Exp. (%chg., TTM, 1y)               0
# SG&A (%chg., TTM, 1y)                  61
# R&D (%chg., TTM, 1y)                  869
# EBIT (%chg., TTM, 1y)                   0
# EBITDA (%chg., TTM, 1y)                17
# Interest, net (%chg., TTM, 1y)        171
# Pretax Inc. (adj) (%chg., TTM, 1y)      0
# Pretax Inc. (%chg., TTM, 1y)            0
# Taxes (%chg., TTM, 1y)                 62
# Income cont. op. (%chg., TTM, 1y)       0
# Net income (%chg., TTM, 1y)             0
# Cash and eq. (%chg., TTM, 1y)           7
# Receivables (%chg., TTM, 1y)          216
# Cur. assets (%chg., TTM, 1y)            3
# PPE (%chg., TTM, 1y)                   18
# Assets (%chg., TTM, 1y)                 7
# Acc. payable (%chg., TTM, 1y)          90
# ST debt (%chg., TTM, 1y)              486
# Cur. liab. (%chg., TTM, 1y)            12
# LT debt (%chg., TTM, 1y)              277
# Debt (%chg., TTM, 1y)                 243
# Liabilities (%chg., TTM, 1y)            7
# Eq. excl. min. (%chg., TTM, 1y)        21
# Minorities (%chg., TTM, 1y)           912
# Equity (%chg., TTM, 1y)                 7
#                                      ...
# Dividends (%chg., TTM, 1y)            751
# Fin. CF (%chg., TTM, 1y)               27
# Cash chg. (%chg., TTM, 1y)             20
# FCF (%chg., TTM, 1y)                   31
# Net Margin (TTM)                       19
# Operating Margin (TTM)                 19
# ROE (TTM)                              10
# ROA (TTM)                              10
# FCF/Net inc. (TTM)                      6
# Current ratio (TTM)                    13
# Liab./Equ. (TTM)                        9
# Debt/Assets (TTM)                       9
# basic EPS (TTM, USD)                   98
# dil. EPS (TTM, USD)                   112
# Sales/Sh. (TTM, USD)                   98
# Book/Sh. (TTM, USD)                    90
# FCF/Sh. (TTM, USD)                     85
# Div./Sh. (TTM, USD)                    92
# P/E (TTM)                              99
# P/S (TTM)                              99
# P/B (TTM)                              90
# P/FCF (TTM)                            85
# MCAP (in million, USD)                 50
# EV (in million, USD)                   10
# EV/EBITDA (TTM)                         0
# EV/Sales (TTM)                         10
# EV/FCF (TTM)                            0
# Book/MCAP                              10
# EBIT/EV (TTM)                          10
# P. F-Score (TTM)                      260
# Length: 65, dtype: int64

# %%
# Most columns have NAs because:
# 1. S&G and R&D are not required expenses, some companies do not use debt, do not pay dividens etc
# so fill NAS with zero values

# %%
combdata4 = combdata3.fillna(0)

# %%
combdata4.isna().values.any()
# Out:
# False

# %%
combdata4.describe()
# Out:
#        Revenues (%chg., TTM, 1y)  COGS (%chg., TTM, 1y)  \
# count                1549.000000            1549.000000
# mean                    0.145249               0.149560
# std                     0.964211               0.752195
# min                    -6.366800              -4.223200
# 25%                     0.023300               0.019500
# 50%                     0.081200               0.078100
# 75%                     0.182800               0.178100
# max                    32.161100              17.550500
#
#        Gross Profit (%chg., TTM, 1y)  Op. Exp. (%chg., TTM, 1y)  \
# count                    1549.000000                1549.000000
# mean                        0.197391                   0.281619
# std                         1.434013                  10.932710
# min                        -6.694900                -141.542100
# 25%                         0.006700                   0.003200
# 50%                         0.079800                   0.077100
# 75%                         0.193100                   0.176900
# max                        37.060200                 406.170700
#
#        SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  EBIT (%chg., TTM, 1y)  \
# count            1549.000000            1549.00000            1549.000000
# mean                0.352294               0.05979               0.273265
# std                10.352233               0.39473               7.066522
# min               -30.987100              -1.38430             -66.567100
# 25%                 0.000000               0.00000              -0.205600
# 50%                 0.075000               0.00000               0.045100
# 75%                 0.169200               0.06170               0.234400
# max               406.170700               8.70870             232.474600
#
#        EBITDA (%chg., TTM, 1y)  Interest, net (%chg., TTM, 1y)  \
# count              1549.000000                     1549.000000
# mean                  0.774798                        0.547226
# std                  22.372267                       11.987357
# min                 -25.132700                     -137.410700
# 25%                  -0.103000                       -0.057100
# 50%                   0.063400                        0.028700
# 75%                   0.222900                        0.232600
# max                 868.958900                      374.227300
#
#        Pretax Inc. (adj) (%chg., TTM, 1y)        ...            P/B (TTM)  \
# count                         1549.000000        ...          1549.000000
# mean                            -0.275788        ...            -7.503066
# std                             19.929646        ...           341.998729
# min                           -741.600000        ...        -12901.460000
# 25%                             -0.257200        ...             1.080000
# 50%                              0.025500        ...             2.390000
# 75%                              0.257200        ...             4.550000
# max                            149.710100        ...           927.260000
#
#         P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# count   1549.000000            1.549000e+03          1.549000e+03
# mean      14.114571            2.639873e+04          2.779442e+04
# std      936.448020            9.689593e+04          8.769049e+04
# min   -24243.180000            0.000000e+00         -1.149803e+02
# 25%        0.000000            6.222241e+02          9.343227e+02
# 50%       11.300000            3.887485e+03          5.468250e+03
# 75%       24.430000            1.369862e+04          1.681746e+04
# max    25587.210000            1.083304e+06          1.004807e+06
#
#        EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)     Book/MCAP  \
# count      1549.000000     1549.000000   1549.000000   1549.000000
# mean       -114.002460        5.744584     23.736566     77.687540
# std        5740.374937       73.368045   1229.543254   1704.290196
# min     -224333.560000      -19.030000 -23461.190000 -37229.230000
# 25%           6.130000        0.950000      2.970000      0.150000
# 50%          11.210000        2.150000     15.010000      0.340000
# 75%          16.620000        4.240000     30.290000      0.630000
# max       21358.020000     2847.110000  41289.940000  19745.600000
#
#        EBIT/EV (TTM)  P. F-Score (TTM)
# count    1549.000000       1549.000000
# mean       -0.044865          4.298257
# std         2.965406          2.522791
# min      -114.870500          0.000000
# 25%         0.013900          3.000000
# 50%         0.047600          5.000000
# 75%         0.072700          6.000000
# max        13.556600          9.000000
#
# [8 rows x 63 columns]

# %%
#Note that percentage change in Revenues, COGS, Gross Profit, etc can be negative, so are EBIT, EBITDA, Book value of equities
# (if liabilities exceed assets)

# %%
combdata4.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 2       21st Century Fox    FOX                     0.0545
# 3        3D SYSTEMS CORP    DDD                     0.0779
# 4                     3M    MMM                     0.0585
# 6           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 2                 0.0861                         0.0007
# 3                 0.0735                         0.0828
# 4                 0.0646                         0.0524
# 6                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 2                     0.0238                 0.0164                0.0000
# 3                     0.0655                 0.0814                0.0220
# 4                     0.1339                 0.1750               -0.0114
# 6                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 2                -0.0141                  -0.0073        ...
# 3                -0.0525                   0.1345        ...
# 4                -0.0454                  -0.0502        ...
# 6                 2.5943                  12.4883        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 2       4.14        17.87            84236.546737         104151.607755
# 3       2.33       -25.20             2045.077054           1313.512819
# 4      11.22        22.51           123317.884925         125106.677466
# 6       6.76       -14.88             1816.977159           1532.456973
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 2            14.77            3.41         20.51       0.24         0.0620
# 3            69.11            1.92        -24.24       0.42        -0.0319
# 4            15.41            3.81         24.34       0.09         0.0532
# 6           -42.78            6.02        -14.09       0.14        -0.0359
#
#    P. F-Score (TTM)
# 0               5.0
# 2               6.0
# 3               0.0
# 4               4.0
# 6               1.0
#
# [5 rows x 65 columns]

# %%
combdata4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1549 entries, 0 to 2512
# Data columns (total 65 columns):
# Name                                  1549 non-null object
# Ticker                                1549 non-null object
# Revenues (%chg., TTM, 1y)             1549 non-null float64
# COGS (%chg., TTM, 1y)                 1549 non-null float64
# Gross Profit (%chg., TTM, 1y)         1549 non-null float64
# Op. Exp. (%chg., TTM, 1y)             1549 non-null float64
# SG&A (%chg., TTM, 1y)                 1549 non-null float64
# R&D (%chg., TTM, 1y)                  1549 non-null float64
# EBIT (%chg., TTM, 1y)                 1549 non-null float64
# EBITDA (%chg., TTM, 1y)               1549 non-null float64
# Interest, net (%chg., TTM, 1y)        1549 non-null float64
# Pretax Inc. (adj) (%chg., TTM, 1y)    1549 non-null float64
# Pretax Inc. (%chg., TTM, 1y)          1549 non-null float64
# Taxes (%chg., TTM, 1y)                1549 non-null float64
# Income cont. op. (%chg., TTM, 1y)     1549 non-null float64
# Net income (%chg., TTM, 1y)           1549 non-null float64
# Cash and eq. (%chg., TTM, 1y)         1549 non-null float64
# Receivables (%chg., TTM, 1y)          1549 non-null float64
# Cur. assets (%chg., TTM, 1y)          1549 non-null float64
# PPE (%chg., TTM, 1y)                  1549 non-null float64
# Assets (%chg., TTM, 1y)               1549 non-null float64
# Acc. payable (%chg., TTM, 1y)         1549 non-null float64
# ST debt (%chg., TTM, 1y)              1549 non-null float64
# Cur. liab. (%chg., TTM, 1y)           1549 non-null float64
# LT debt (%chg., TTM, 1y)              1549 non-null float64
# Debt (%chg., TTM, 1y)                 1549 non-null float64
# Liabilities (%chg., TTM, 1y)          1549 non-null float64
# Eq. excl. min. (%chg., TTM, 1y)       1549 non-null float64
# Minorities (%chg., TTM, 1y)           1549 non-null float64
# Equity (%chg., TTM, 1y)               1549 non-null float64
# D&A (%chg., TTM, 1y)                  1549 non-null float64
# Chg. WC (%chg., TTM, 1y)              1549 non-null float64
# Op. CF (%chg., TTM, 1y)               1549 non-null float64
# Chg. in PP&E (%chg., TTM, 1y)         1549 non-null float64
# Inv. CF (%chg., TTM, 1y)              1549 non-null float64
# Dividends (%chg., TTM, 1y)            1549 non-null float64
# Fin. CF (%chg., TTM, 1y)              1549 non-null float64
# Cash chg. (%chg., TTM, 1y)            1549 non-null float64
# FCF (%chg., TTM, 1y)                  1549 non-null float64
# Net Margin (TTM)                      1549 non-null float64
# Operating Margin (TTM)                1549 non-null float64
# ROE (TTM)                             1549 non-null float64
# ROA (TTM)                             1549 non-null float64
# FCF/Net inc. (TTM)                    1549 non-null float64
# Current ratio (TTM)                   1549 non-null float64
# Liab./Equ. (TTM)                      1549 non-null float64
# Debt/Assets (TTM)                     1549 non-null float64
# basic EPS (TTM, USD)                  1549 non-null float64
# dil. EPS (TTM, USD)                   1549 non-null float64
# Sales/Sh. (TTM, USD)                  1549 non-null float64
# Book/Sh. (TTM, USD)                   1549 non-null float64
# FCF/Sh. (TTM, USD)                    1549 non-null float64
# Div./Sh. (TTM, USD)                   1549 non-null float64
# P/E (TTM)                             1549 non-null float64
# P/S (TTM)                             1549 non-null float64
# P/B (TTM)                             1549 non-null float64
# P/FCF (TTM)                           1549 non-null float64
# MCAP (in million, USD)                1549 non-null float64
# EV (in million, USD)                  1549 non-null float64
# EV/EBITDA (TTM)                       1549 non-null float64
# EV/Sales (TTM)                        1549 non-null float64
# EV/FCF (TTM)                          1549 non-null float64
# Book/MCAP                             1549 non-null float64
# EBIT/EV (TTM)                         1549 non-null float64
# P. F-Score (TTM)                      1549 non-null float64
# dtypes: float64(63), object(2)
# memory usage: 798.7+ KB

# %%
combdata5 = combdata4.reset_index(drop=True)

# %%
combdata5.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1       21st Century Fox    FOX                     0.0545
# 2        3D SYSTEMS CORP    DDD                     0.0779
# 3                     3M    MMM                     0.0585
# 4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)        ...         \
# 0                -0.2443                  -0.1610        ...
# 1                -0.0141                  -0.0073        ...
# 2                -0.0525                   0.1345        ...
# 3                -0.0454                  -0.0502        ...
# 4                 2.5943                  12.4883        ...
#
#    P/B (TTM)  P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  \
# 0       2.72        18.52              720.839700            879.482310
# 1       4.14        17.87            84236.546737         104151.607755
# 2       2.33       -25.20             2045.077054           1313.512819
# 3      11.22        22.51           123317.884925         125106.677466
# 4       6.76       -14.88             1816.977159           1532.456973
#
#    EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  \
# 0            12.00            0.72         20.29       0.37         0.0449
# 1            14.77            3.41         20.51       0.24         0.0620
# 2            69.11            1.92        -24.24       0.42        -0.0319
# 3            15.41            3.81         24.34       0.09         0.0532
# 4           -42.78            6.02        -14.09       0.14        -0.0359
#
#    P. F-Score (TTM)
# 0               5.0
# 1               6.0
# 2               0.0
# 3               4.0
# 4               1.0
#
# [5 rows x 65 columns]

# %%
combdata5.to_csv('cleandata.csv') #writing the cleaned data to csv

# %%
combdata5["Ticker"].nunique()
# Out:
# 1350

# %%
combdata5["Name"].nunique()
# Out:
# 1363

# %%
# Duplicate Names and companies, need to drop duplicates

# %%
combdata6 = combdata5.drop_duplicates(['Ticker'])

# %%
combdata6['Ticker'].nunique()
# Out:
# 1350

# %%
combdata6['Name'].nunique()
# Out:
# 1350

# %%
combdata6.shape
# Out:
# (1350, 65)

# %%
combdata7 = combdata6.reset_index(drop=True)

# %%
combdata7.to_csv('cleandata1.csv')

# %% [markdown]
# ## Loading Fundamental and Return Data

# %%
funda = pd.read_csv('cleandata1.csv')
priceRet = pd.read_excel('Ticker Symbol Return.xlsx')

# %%
funda.head()
# Out:
#    Unnamed: 0                   Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0           0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1           1       21st Century Fox    FOX                     0.0545
# 2           2        3D SYSTEMS CORP    DDD                     0.0779
# 3           3                     3M    MMM                     0.0585
# 4           4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)        ...         P/B (TTM)  P/FCF (TTM)  \
# 0                -0.2443        ...              2.72        18.52
# 1                -0.0141        ...              4.14        17.87
# 2                -0.0525        ...              2.33       -25.20
# 3                -0.0454        ...             11.22        22.51
# 4                 2.5943        ...              6.76       -14.88
#
#    MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0              720.839700            879.482310            12.00
# 1            84236.546737         104151.607755            14.77
# 2             2045.077054           1313.512819            69.11
# 3           123317.884925         125106.677466            15.41
# 4             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)
# 0            0.72         20.29       0.37         0.0449               5.0
# 1            3.41         20.51       0.24         0.0620               6.0
# 2            1.92        -24.24       0.42        -0.0319               0.0
# 3            3.81         24.34       0.09         0.0532               4.0
# 4            6.02        -14.09       0.14        -0.0359               1.0
#
# [5 rows x 66 columns]

# %%
priceRet.head()
# Out:
#   Ticker    Return
# 0   FLWS  0.107477
# 1    FOX  0.401115
# 2    DDD  0.140251
# 3    MMM -0.190989
# 4   EGHT  0.263860

# %%
funda.shape, priceRet.shape
# Out:
# ((1350, 66), (1089, 2))

# %%
# Merging both files
fundRet = pd.merge(funda, priceRet, how='left',on='Ticker')

# %%
fundRet.shape
# Out:
# (1350, 67)

# %%
fundRet.head()
# Out:
#    Unnamed: 0                   Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0           0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1           1       21st Century Fox    FOX                     0.0545
# 2           2        3D SYSTEMS CORP    DDD                     0.0779
# 3           3                     3M    MMM                     0.0585
# 4           4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)    ...     P/FCF (TTM)  MCAP (in million, USD)  \
# 0                -0.2443    ...           18.52              720.839700
# 1                -0.0141    ...           17.87            84236.546737
# 2                -0.0525    ...          -25.20             2045.077054
# 3                -0.0454    ...           22.51           123317.884925
# 4                 2.5943    ...          -14.88             1816.977159
#
#    EV (in million, USD)  EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  \
# 0            879.482310            12.00            0.72         20.29
# 1         104151.607755            14.77            3.41         20.51
# 2           1313.512819            69.11            1.92        -24.24
# 3         125106.677466            15.41            3.81         24.34
# 4           1532.456973           -42.78            6.02        -14.09
#
#    Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)    Return
# 0       0.37         0.0449               5.0  0.107477
# 1       0.24         0.0620               6.0  0.401115
# 2       0.42        -0.0319               0.0  0.140251
# 3       0.09         0.0532               4.0 -0.190989
# 4       0.14        -0.0359               1.0  0.263860
#
# [5 rows x 67 columns]

# %%
# Drop rows with NAs in Return column
fundRet1 = fundRet.dropna(subset=["Return"])

# %%
fundRet1.shape
# Out:
# (1083, 67)

# %%
fundRet1.isna().values.any()
# Out:
# False

# %%
fundRet1.columns.get_loc("Unnamed: 0")
# Out:
# 0

# %%
fundRet1.head()
# Out:
#    Unnamed: 0                   Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0           0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1           1       21st Century Fox    FOX                     0.0545
# 2           2        3D SYSTEMS CORP    DDD                     0.0779
# 3           3                     3M    MMM                     0.0585
# 4           4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)    ...     P/FCF (TTM)  MCAP (in million, USD)  \
# 0                -0.2443    ...           18.52              720.839700
# 1                -0.0141    ...           17.87            84236.546737
# 2                -0.0525    ...          -25.20             2045.077054
# 3                -0.0454    ...           22.51           123317.884925
# 4                 2.5943    ...          -14.88             1816.977159
#
#    EV (in million, USD)  EV/EBITDA (TTM)  EV/Sales (TTM)  EV/FCF (TTM)  \
# 0            879.482310            12.00            0.72         20.29
# 1         104151.607755            14.77            3.41         20.51
# 2           1313.512819            69.11            1.92        -24.24
# 3         125106.677466            15.41            3.81         24.34
# 4           1532.456973           -42.78            6.02        -14.09
#
#    Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)    Return
# 0       0.37         0.0449               5.0  0.107477
# 1       0.24         0.0620               6.0  0.401115
# 2       0.42        -0.0319               0.0  0.140251
# 3       0.09         0.0532               4.0 -0.190989
# 4       0.14        -0.0359               1.0  0.263860
#
# [5 rows x 67 columns]

# %%
fundRet2 = fundRet1.drop(fundRet1.columns[[0]], axis=1) #Drop index column 'Unnamed 0'

# %%
fundRet2.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1       21st Century Fox    FOX                     0.0545
# 2        3D SYSTEMS CORP    DDD                     0.0779
# 3                     3M    MMM                     0.0585
# 4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)    ...     P/FCF (TTM)  \
# 0                -0.2443                  -0.1610    ...           18.52
# 1                -0.0141                  -0.0073    ...           17.87
# 2                -0.0525                   0.1345    ...          -25.20
# 3                -0.0454                  -0.0502    ...           22.51
# 4                 2.5943                  12.4883    ...          -14.88
#
#    MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0              720.839700            879.482310            12.00
# 1            84236.546737         104151.607755            14.77
# 2             2045.077054           1313.512819            69.11
# 3           123317.884925         125106.677466            15.41
# 4             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)  \
# 0            0.72         20.29       0.37         0.0449               5.0
# 1            3.41         20.51       0.24         0.0620               6.0
# 2            1.92        -24.24       0.42        -0.0319               0.0
# 3            3.81         24.34       0.09         0.0532               4.0
# 4            6.02        -14.09       0.14        -0.0359               1.0
#
#      Return
# 0  0.107477
# 1  0.401115
# 2  0.140251
# 3 -0.190989
# 4  0.263860
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Exploratory Data Analytics

# %%
fundRet2[["Return"]].plot(kind='kde');

# %%
plt.rcParams['figure.figsize']=(16,8)
plt.style.use('ggplot')
cormat = fundRet2.corr()
sns.heatmap(cormat, square=True);

# %% [markdown]
# ## Predictive Analytics

# %%
# Importing the Libraries
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report,accuracy_score
import scikitplot as skplt
from sklearn.metrics import *
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn import preprocessing, metrics
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.model_selection import GridSearchCV
import scikitplot as skplt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ### Stocks Return Distribution

# %%
# Checking for Data Distribution of the dependent variable
fundRet2[["Return"]].describe()
# Out:
#             Return
# count  1083.000000
# mean     -0.088828
# std       0.604901
# min      -0.999888
# 25%      -0.332220
# 50%      -0.138554
# 75%       0.043283
# max      13.929168

# %% [markdown]
# ### Benchmarking Stock Returns using a Market or Index Return: S&P500

# %%
#Loading the market index S&P
index = pd.read_csv('GSPC S&P.csv')

# %%
index.shape
# Out:
# (253, 7)

# %%
index.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  12/27/2017  2682.100098  2685.639893  2678.909912  2682.620117
# 1  12/28/2017  2686.100098  2687.659912  2682.689941  2687.540039
# 2  12/29/2017  2689.149902  2692.120117  2673.610107  2673.610107
# 3    1/2/2018  2683.729980  2695.889893  2682.360107  2695.810059
# 4    1/3/2018  2697.850098  2714.370117  2697.770020  2713.060059
#
#      Adj Close      Volume
# 0  2682.620117  2202080000
# 1  2687.540039  2153330000
# 2  2673.610107  2443490000
# 3  2695.810059  3367250000
# 4  2713.060059  3538660000

# %%
index[["Close"]].plot();

# %%
# Index Annual Return using 252-days interval
ixRet = (index[["Close"]].loc[252]/index[["Close"]].loc[0])-1
ixRet
# Out:
# Close   -0.073391
# dtype: float64

# %%
# S&P Average Return within the period is 0.07339 or 7.3% 
# The average stock return of -8.9% is close to the market average given the fact that the market index
# is made up of a sample of the constituent stocks and the composition of the index does not change frequently
# Negative Performance for the index happened mostly in the last 60 days
# Thus, Annual Return using Daily Compounding will be computed for comparison

# %%
#Annual Return compounded daily
dailyRet = index["Close"].pct_change(1).sum()
dailyRet
# Out:
# -0.061762537668957784

# %%
#Annual Return compounded yearly
yearlyRet = index["Close"].pct_change(252).sum()
yearlyRet
# Out:
# -0.07339098285007017

# %%
# Annual Return compounded daily is slightly higher given the fall in prices largely occured in the last 60 days.

# %% [markdown]
# ### Return Classification, benchamrked to Index Return

# %%
# Stock Returns will be classified and benchmarked to the market return. 
#Stocks with Return:
# <= -0.073 shall be classified as bad stocks, implying that investors are likely going to lose money, thus assigned 1
# > -0.073 shall be classified as good stocks. These are stocks that investors may not lose money, thus assigned 0

# %%
# Change the object from fundRet2 to dataset for easy referencing
dataset = fundRet2

# %%
dataset.to_csv('dataset.csv')

# %%
dataset.loc[dataset['Return']<=0.073, 'Loss'] = 1
dataset.loc[dataset['Return']>0.073, 'Loss'] = 0

# %%
dataset.head()
# Out:
#                     Name Ticker  Revenues (%chg., TTM, 1y)  \
# 0  1 800 FLOWERS COM INC   FLWS                    -0.0178
# 1       21st Century Fox    FOX                     0.0545
# 2        3D SYSTEMS CORP    DDD                     0.0779
# 3                     3M    MMM                     0.0585
# 4           8X8 INC /DE/   EGHT                    -0.0626
#
#    COGS (%chg., TTM, 1y)  Gross Profit (%chg., TTM, 1y)  \
# 0                 0.0072                        -0.0501
# 1                 0.0861                         0.0007
# 2                 0.0735                         0.0828
# 3                 0.0646                         0.0524
# 4                -0.0204                        -0.0757
#
#    Op. Exp. (%chg., TTM, 1y)  SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  \
# 0                    -0.0294                -0.0337                0.0200
# 1                     0.0238                 0.0164                0.0000
# 2                     0.0655                 0.0814                0.0220
# 3                     0.1339                 0.1750               -0.0114
# 4                     0.1077                 0.0876                0.2346
#
#    EBIT (%chg., TTM, 1y)  EBITDA (%chg., TTM, 1y)  ...   \
# 0                -0.2443                  -0.1610  ...
# 1                -0.0141                  -0.0073  ...
# 2                -0.0525                   0.1345  ...
# 3                -0.0454                  -0.0502  ...
# 4                 2.5943                  12.4883  ...
#
#    MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0              720.839700            879.482310            12.00
# 1            84236.546737         104151.607755            14.77
# 2             2045.077054           1313.512819            69.11
# 3           123317.884925         125106.677466            15.41
# 4             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)  \
# 0            0.72         20.29       0.37         0.0449               5.0
# 1            3.41         20.51       0.24         0.0620               6.0
# 2            1.92        -24.24       0.42        -0.0319               0.0
# 3            3.81         24.34       0.09         0.0532               4.0
# 4            6.02        -14.09       0.14        -0.0359               1.0
#
#      Return  Loss
# 0  0.107477   0.0
# 1  0.401115   0.0
# 2  0.140251   0.0
# 3 -0.190989   1.0
# 4  0.263860   0.0
#
# [5 rows x 67 columns]

# %%
#Checking for the distribution of RetClass
dataset[['Loss']].plot(kind='hist');

# %%
# Clearly, this is an imbalanced dataset

# %%
dataset[['Loss']].count().sum()
# Out:
# 1083

# %%
dataset.groupby('Loss')['Loss'].count()/dataset['Loss'].count().sum()
# Out:
# Loss
# 0.0    0.221607
# 1.0    0.778393
# Name: Loss, dtype: float64

# %%
# The distribution of the dependent variable is imbalanced, (Loss category 0 makes up less than a quarter of the entire dataset),
#so we run ML algorithms on both this data and a resampled data later

# %% [markdown]
# ## Data Preprocessing Part B

# %% [markdown]
# ### Using An Imbalanced Dataset

# %%
dataset.columns.get_loc("P. F-Score (TTM)")
# Out:
# 64

# %%
#Selecting the Features
X = dataset.iloc[:,2:65]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    Revenues (%chg., TTM, 1y)  COGS (%chg., TTM, 1y)  \
# 0                    -0.0178                 0.0072
# 1                     0.0545                 0.0861
# 2                     0.0779                 0.0735
# 3                     0.0585                 0.0646
# 4                    -0.0626                -0.0204
#
#    Gross Profit (%chg., TTM, 1y)  Op. Exp. (%chg., TTM, 1y)  \
# 0                        -0.0501                    -0.0294
# 1                         0.0007                     0.0238
# 2                         0.0828                     0.0655
# 3                         0.0524                     0.1339
# 4                        -0.0757                     0.1077
#
#    SG&A (%chg., TTM, 1y)  R&D (%chg., TTM, 1y)  EBIT (%chg., TTM, 1y)  \
# 0                -0.0337                0.0200                -0.2443
# 1                 0.0164                0.0000                -0.0141
# 2                 0.0814                0.0220                -0.0525
# 3                 0.1750               -0.0114                -0.0454
# 4                 0.0876                0.2346                 2.5943
#
#    EBITDA (%chg., TTM, 1y)  Interest, net (%chg., TTM, 1y)  \
# 0                  -0.1610                         -0.3353
# 1                  -0.0073                          0.0025
# 2                   0.1345                          9.1778
# 3                  -0.0502                          2.9634
# 4                  12.4883                          0.0000
#
#    Pretax Inc. (adj) (%chg., TTM, 1y)        ...         P/B (TTM)  \
# 0                             -0.4219        ...              2.72
# 1                             -0.0566        ...              4.14
# 2                             -0.0058        ...              2.33
# 3                             -0.0812        ...             11.22
# 4                              3.6213        ...              6.76
#
#    P/FCF (TTM)  MCAP (in million, USD)  EV (in million, USD)  EV/EBITDA (TTM)  \
# 0        18.52              720.839700            879.482310            12.00
# 1        17.87            84236.546737         104151.607755            14.77
# 2       -25.20             2045.077054           1313.512819            69.11
# 3        22.51           123317.884925         125106.677466            15.41
# 4       -14.88             1816.977159           1532.456973           -42.78
#
#    EV/Sales (TTM)  EV/FCF (TTM)  Book/MCAP  EBIT/EV (TTM)  P. F-Score (TTM)
# 0            0.72         20.29       0.37         0.0449               5.0
# 1            3.41         20.51       0.24         0.0620               6.0
# 2            1.92        -24.24       0.42        -0.0319               0.0
# 3            3.81         24.34       0.09         0.0532               4.0
# 4            6.02        -14.09       0.14        -0.0359               1.0
#
# [5 rows x 63 columns]

# %%
y.head()
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    0.0
# Name: Loss, dtype: float64

# %% [markdown]
# ### Splitting the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 123)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((812, 63), (271, 63), (812,), (271,))

# %% [markdown]
# ### Scaling the features

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Building the Algorithms

# %%
clf1 = KNeighborsClassifier()
clf2 = RandomForestClassifier(random_state=1)
clf3 = GaussianNB()
lr = LogisticRegression()
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)

# %%
# Dictionary of different classifiers
clfs = {
'LogisticRegression' : LogisticRegression(),
'DecisionTree': DecisionTreeClassifier(),
'KNNClassifier': KNeighborsClassifier(),
'NaiveBayes': GaussianNB(),
'SupportVectorMachines': SVC(kernel="poly"),
'Bagging': BaggingClassifier(),
'AdaBoostClassifier': AdaBoostClassifier(),
'RandomForestClassifier': RandomForestClassifier(),
'GradientBoostingClassifier': GradientBoostingClassifier(),
'XGBoost': XGBClassifier(),
'StackingClassifier': StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)
}

# %%
# Testing all clfs models and generating a report
models_report = pd.DataFrame(columns = ['Model', 'Accuracy','Precision_score', 'Recall_score','F1_score', 'AUC'])

for clf, clf_name in zip(clfs.values(), clfs.keys()):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    y_score = clf.score(X_test,y_test)
    
    #print('Calculating {}'.format(clf_name))
    t = pd.Series({ 
                     'Model': clf_name,
                     'Precision_score': metrics.precision_score(y_test, y_pred),
                     'Recall_score': metrics.recall_score(y_test, y_pred),
                     'F1_score': metrics.f1_score(y_test, y_pred),
                     'Accuracy': metrics.accuracy_score(y_test, y_pred),
                     'AUC': metrics.roc_auc_score(y_test, y_pred)}
                   )

    models_report = models_report.append(t, ignore_index = True)

models_report
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                          Model  Accuracy  Precision_score  Recall_score  \
# 0           LogisticRegression  0.719557         0.747036      0.940299
# 1                 DecisionTree  0.690037         0.779904      0.810945
# 2                KNNClassifier  0.693727         0.736000      0.915423
# 3                   NaiveBayes  0.704797         0.768889      0.860697
# 4        SupportVectorMachines  0.730627         0.742424      0.975124
# 5                      Bagging  0.749077         0.798206      0.885572
# 6           AdaBoostClassifier  0.771218         0.806167      0.910448
# 7       RandomForestClassifier  0.774908         0.815315      0.900498
# 8   GradientBoostingClassifier  0.756458         0.784810      0.925373
# 9                      XGBoost  0.760148         0.783333      0.935323
# 10          StackingClassifier  0.741697         0.783550      0.900498
#
#     F1_score       AUC
# 0   0.832599  0.513006
# 1   0.795122  0.576901
# 2   0.815965  0.486283
# 3   0.812207  0.558920
# 4   0.843011  0.501848
# 5   0.839623  0.621357
# 6   0.855140  0.640938
# 7   0.855792  0.657392
# 8   0.849315  0.598401
# 9   0.852608  0.596233
# 10  0.837963  0.593106

# %%
# Given the imbalanced nature of the dataset, accuracy scores of 78% is not different from the data distrbution.
# Also, accuracy is not the right metric for an imbalanced dataset such as this, thus, other metrics may need to be considered.
# Precision for the positive class is: among all the predicted positive class, what fraction was correct (TP/(TP+FP)).
# Recall for the positive class is: among all actuall positive class category (ground truth for good stocks), 
# what fraction did the classifiers predict correctly (TP/(TP+FN))

#Observations Explanations:
# Recall across all the algorithms are higher than Precision. 
# Performance metrics across all algorithms are lower for class 0 even after tuning the hyperparameters (see below)
# Given there are less datapoints for positives (class 0 or good stocks), it is generally easier for the classifiers 
# to have fewer false negatives (good stocks wrongly classified as bad stocks). Also, given there are more datapoints 
# for the negative class (class 1 or bad stocks), it is not unusual to expect to have more 
# false positives (bad stocks wrongly classified as good stocks) than false negatives.
# Thus, Precision is expected to be lower across board.

# %% [markdown]
# ## Tuning the hyperparameters using GridSearch/RandomSearch

# %%
# GridSearch is more computationally expensive, hence, RandomSearch was substituted for some of the algorithms

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier()
rf_params = {'n_estimators': np.arange(50,500,50)}
rf_grid = GridSearchCV(rf, rf_params, cv=5)
rf_grid.fit(X_train, y_train)
y_pred_rf = rf_grid.predict(X_test)
rf_nested_score = cross_val_score(rf_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_rf)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_rf)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_rf)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_rf)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_rf)))
rf_grid.best_params_
# Out:
# Accuracy Score is 0.771218
# Precision Score is 0.779116
# Recall Score is 0.965174
# F1_score is 0.862222
# AUC Score is 0.589730
# {'n_estimators': 300}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(rf_nested_score.mean(), rf_nested_score.std()))
# Out:
# mean of 0.806093 with std. dev. of 0.008260.

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[ 15  55]
#  [  7 194]]

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.21      0.33        70
#          1.0       0.78      0.97      0.86       201
#
#    micro avg       0.77      0.77      0.77       271
#    macro avg       0.73      0.59      0.59       271
# weighted avg       0.75      0.77      0.72       271

# %%
rf = RandomForestClassifier(n_estimators=300)
rf = rf.fit(X_train, y_train)
y_probas = rf.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False, figsize=(8,6))

rf = RandomForestClassifier(n_estimators=300)
rf = rf.fit(X_train, y_train)
y_probas = rf.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas, figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
svm = SVC('linear')
svm_params = {'C': [0.1,100,1000], 'gamma':[0.001,0.01,10]}
svm_grid = GridSearchCV(svm, svm_params, cv=5)
#svm_grid = RandomizedSearchCV(svm, param_distributions=svm_params, refit=True, cv=3)
svm_grid.fit(X_train, y_train)
y_pred_svm = svm_grid.predict(X_test)
svm_nested_score = cross_val_score(svm_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_svm)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_svm)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_svm)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_svm)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_svm)))
svm_grid.best_params_
# Out:
# Accuracy Score is 0.741697
# Precision Score is 0.741697
# Recall Score is 1.000000
# F1_score is 0.851695
# AUC Score is 0.500000
# {'C': 0.1, 'gamma': 0.001}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(svm_nested_score.mean(), svm_nested_score.std()))
# Out:
# mean of 0.778392 with std. dev. of 0.000502.

# %%
print(confusion_matrix(y_test, y_pred_svm))
# Out:
# [[  0  70]
#  [  0 201]]

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        70
#          1.0       0.74      1.00      0.85       201
#
#    micro avg       0.74      0.74      0.74       271
#    macro avg       0.37      0.50      0.43       271
# weighted avg       0.55      0.74      0.63       271
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svm = SVC(kernel='linear', gamma=0.001, C=0.1, probability=True)
svm = svm.fit(X_train, y_train)
y_probas = svm.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

svm = SVC(kernel='linear', gamma=0.001, C=0.1, probability=True)
svm = svm.fit(X_train, y_train)
y_probas = svm.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression()
lr_params = {'C': [0.1, 10.0, 100, 1000]}
lr_grid = GridSearchCV(lr, lr_params, cv=5)
lr_grid.fit(X_train, y_train)
y_pred_lr = lr_grid.predict(X_test)
lr_nested_score = cross_val_score(lr_grid, X, y, cv=5)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_lr)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_lr)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_lr)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_lr)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_lr)))
lr_grid.best_params_
# Out:
# Accuracy Score is 0.726937
# Precision Score is 0.749020
# Recall Score is 0.950249
# F1_score is 0.837719
# AUC Score is 0.517982
# {'C': 0.1}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(lr_nested_score.mean(), lr_nested_score.std()))
# Out:
# mean of 0.755274 with std. dev. of 0.019585.

# %%
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# [[  6  64]
#  [ 10 191]]

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.09      0.14        70
#          1.0       0.75      0.95      0.84       201
#
#    micro avg       0.73      0.73      0.73       271
#    macro avg       0.56      0.52      0.49       271
# weighted avg       0.65      0.73      0.66       271

# %%
lr = LogisticRegression(C=0.1)
lr = lr.fit(X_train, y_train)
y_probas = lr.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

lr = LogisticRegression(C=0.1)
lr = lr.fit(X_train, y_train)
y_probas = lr.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier()
dt_params = {'max_depth': np.arange(3,12,1),'min_samples_split':np.arange(2,10,1),'min_samples_leaf':np.arange(1,10,1)}
dt_grid = GridSearchCV(dt, dt_params, cv=5)
dt_grid.fit(X_train, y_train)
y_pred_dt = dt_grid.predict(X_test)
dt_nested_score = cross_val_score(dt_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_dt)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_dt)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_dt)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_dt)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_dt)))
dt_grid.best_params_
# Out:
# Accuracy Score is 0.723247
# Precision Score is 0.769231
# Recall Score is 0.895522
# F1_score is 0.827586
# AUC Score is 0.562047
# {'max_depth': 3, 'min_samples_leaf': 8, 'min_samples_split': 2}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(dt_nested_score.mean(), dt_nested_score.std()))
# Out:
# mean of 0.786683 with std. dev. of 0.020502.

# %%
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# [[ 16  54]
#  [ 21 180]]

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.23      0.30        70
#          1.0       0.77      0.90      0.83       201
#
#    micro avg       0.72      0.72      0.72       271
#    macro avg       0.60      0.56      0.56       271
# weighted avg       0.68      0.72      0.69       271

# %%
dt = DecisionTreeClassifier(max_depth=3, min_samples_leaf=8, min_samples_split=2)
dt = dt.fit(X_train, y_train)
y_probas = dt.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

dt = DecisionTreeClassifier(max_depth=3, min_samples_leaf=8, min_samples_split=2)
dt = dt.fit(X_train, y_train)
y_probas = dt.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### K-Nearest Neigbor (KNN)

# %%
knn = KNeighborsClassifier()
knn_params = {'n_neighbors': np.arange(2,15,1), 'leaf_size':np.arange(3,15,1)}
knn_grid = GridSearchCV(knn, knn_params, cv=5)
knn_grid.fit(X_train, y_train)
y_pred_knn = knn_grid.predict(X_test)
knn_nested_score = cross_val_score(knn_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_knn)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_knn)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_knn)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_knn)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_knn)))
knn_grid.best_params_
# Out:
# Accuracy Score is 0.741697
# Precision Score is 0.749049
# Recall Score is 0.980100
# F1_score is 0.849138
# AUC Score is 0.518621
# {'leaf_size': 3, 'n_neighbors': 9}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(knn_nested_score.mean(), knn_nested_score.std()))
# Out:
# mean of 0.773775 with std. dev. of 0.006561.

# %%
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# [[  4  66]
#  [  4 197]]

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.06      0.10        70
#          1.0       0.75      0.98      0.85       201
#
#    micro avg       0.74      0.74      0.74       271
#    macro avg       0.62      0.52      0.48       271
# weighted avg       0.68      0.74      0.66       271

# %%
knn = KNeighborsClassifier(n_neighbors=9, leaf_size=3)
knn = knn.fit(X_train, y_train)
y_probas = knn.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

knn = KNeighborsClassifier(n_neighbors=9, leaf_size=3)
knn = knn.fit(X_train, y_train)
y_probas = knn.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Naive Bayes

# %%
nb = GaussianNB()
nb_params = {'var_smoothing': [1e-12, 1e-11, 1e-10, 1e-09, 1e-08, 1e-07]}
nb_grid = GridSearchCV(nb, nb_params, cv=5)
nb_grid.fit(X_train, y_train)
y_pred_nb = nb_grid.predict(X_test)
nb_nested_score = cross_val_score(nb_grid, X, y, cv=5)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_nb)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_nb)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_nb)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_nb)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_nb)))
nb_grid.best_params_
# Out:
# Accuracy Score is 0.704797
# Precision Score is 0.768889
# Recall Score is 0.860697
# F1_score is 0.812207
# AUC Score is 0.558920
# {'var_smoothing': 1e-12}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(nb_nested_score.mean(), nb_nested_score.std()))
# Out:
# mean of 0.543770 with std. dev. of 0.203500.

# %%
print(confusion_matrix(y_test, y_pred_nb))
# Out:
# [[ 18  52]
#  [ 28 173]]

# %%
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.26      0.31        70
#          1.0       0.77      0.86      0.81       201
#
#    micro avg       0.70      0.70      0.70       271
#    macro avg       0.58      0.56      0.56       271
# weighted avg       0.67      0.70      0.68       271

# %%
nb = GaussianNB(var_smoothing=1e-12)
nb = nb.fit(X_train, y_train)
y_probas = nb.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

nb = GaussianNB(var_smoothing=1e-12)
nb = nb.fit(X_train, y_train)
y_probas = nb.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Ada Boost

# %%
ab = AdaBoostClassifier()
ab_params = {'n_estimators': np.arange(50,500,50),'learning_rate':np.arange(0.4,2.0,0.2)}
ab_grid = GridSearchCV(ab, ab_params, cv=3)
ab_grid.fit(X_train, y_train)
y_pred_ab = ab_grid.predict(X_test)
ab_nested_score = cross_val_score(ab_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_ab)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_ab)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_ab)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_ab)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_ab)))
ab_grid.best_params_
# Out:
# Accuracy Score is 0.756458
# Precision Score is 0.794760
# Recall Score is 0.905473
# F1_score is 0.846512
# AUC Score is 0.617022
# {'learning_rate': 0.6000000000000001, 'n_estimators': 50}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(ab_nested_score.mean(), ab_nested_score.std()))
# Out:
# mean of 0.804250 with std. dev. of 0.010306.

# %%
print(confusion_matrix(y_test, y_pred_ab))
# Out:
# [[ 23  47]
#  [ 19 182]]

# %%
print(classification_report(y_test, y_pred_ab))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.33      0.41        70
#          1.0       0.79      0.91      0.85       201
#
#    micro avg       0.76      0.76      0.76       271
#    macro avg       0.67      0.62      0.63       271
# weighted avg       0.73      0.76      0.73       271

# %%
ab = AdaBoostClassifier(learning_rate=0.6, n_estimators=50)
ab = ab.fit(X_train, y_train)
y_probas = ab.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

ab = AdaBoostClassifier(learning_rate=0.6, n_estimators=50)
ab = ab.fit(X_train, y_train)
y_probas = ab.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Gradient Boosting

# %%
gb = GradientBoostingClassifier()
gb_params = {'n_estimators': np.arange(100,500,50),'learning_rate' : np.arange(0.01,0.1,0.02), 'max_depth':np.arange(3,11,2)}
gb_grid = GridSearchCV(gb, gb_params, cv=5)
#gb_grid = RandomizedSearchCV(gb, param_distributions=gb_params, refit=True)
gb_grid.fit(X_train, y_train)
y_pred_gb = gb_grid.predict(X_test)
gb_nested_score = cross_val_score(gb_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_gb)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_gb)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_gb)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_gb)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_gb)))
gb_grid.best_params_
# Out:
# Accuracy Score is 0.767528
# Precision Score is 0.780488
# Recall Score is 0.955224
# F1_score is 0.859060
# AUC Score is 0.591898
# {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 100}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(gb_nested_score.mean(), gb_nested_score.std()))
# Out:
# mean of 0.807002 with std. dev. of 0.016305.

# %%
print(confusion_matrix(y_test, y_pred_gb))
# Out:
# [[ 16  54]
#  [  9 192]]

# %%
print(classification_report(y_test, y_pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.23      0.34        70
#          1.0       0.78      0.96      0.86       201
#
#    micro avg       0.77      0.77      0.77       271
#    macro avg       0.71      0.59      0.60       271
# weighted avg       0.74      0.77      0.72       271

# %%
gb = GradientBoostingClassifier(learning_rate=0.03, n_estimators=100, max_depth= 3)
gb = gb.fit(X_train, y_train)
y_probas = gb.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

gb = GradientBoostingClassifier(learning_rate=0.03, n_estimators=100, max_depth= 3)
gb = gb.fit(X_train, y_train)
y_probas = gb.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Bagging

# %%
bg = BaggingClassifier()
bg_params = {'n_estimators': np.arange(4,20,2)}
bg_grid = GridSearchCV(bg, bg_params, cv=5)
bg_grid.fit(X_train, y_train)
y_pred_bg = bg_grid.predict(X_test)
bg_nested_score = cross_val_score(bg_grid, X, y, cv=5)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_bg)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_bg)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_bg)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_bg)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_bg)))
bg_grid.best_params_
# Out:
# Accuracy Score is 0.741697
# Precision Score is 0.781116
# Recall Score is 0.905473
# F1_score is 0.838710
# AUC Score is 0.588451
# {'n_estimators': 14}

# %%
print("mean of {0:6f} with std. dev. of {1:6f}.".format(bg_nested_score.mean(), bg_nested_score.std()))
# Out:
# mean of 0.807941 with std. dev. of 0.017656.

# %%
print(confusion_matrix(y_test, y_pred_bg))
# Out:
# [[ 19  51]
#  [ 19 182]]

# %%
print(classification_report(y_test, y_pred_bg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.27      0.35        70
#          1.0       0.78      0.91      0.84       201
#
#    micro avg       0.74      0.74      0.74       271
#    macro avg       0.64      0.59      0.60       271
# weighted avg       0.71      0.74      0.71       271

# %%
bg = BaggingClassifier(n_estimators=14)
bg = bg.fit(X_train, y_train)
y_probas = bg.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

bg = BaggingClassifier(n_estimators=14)
bg = bg.fit(X_train, y_train)
y_probas = bg.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Stacking Classifier

# %%
clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=50)
clf2 = GradientBoostingClassifier(learning_rate=0.03, n_estimators=100, max_depth= 3)
clf3 = BaggingClassifier(n_estimators=14)
rf = RandomForestClassifier(n_estimators=300)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf.fit(X_train, y_train)
y_pred_sclf = bg_grid.predict(X_test)

# %%
print("Accuracy Score is {0:6f}".format(metrics.accuracy_score(y_test, y_pred_sclf)))
print("Precision Score is {0:6f}".format(metrics.precision_score(y_test, y_pred_sclf)))
print("Recall Score is {0:6f}".format(metrics.recall_score(y_test, y_pred_sclf)))
print("F1_score is {0:6f}".format(metrics.f1_score(y_test, y_pred_sclf)))
print("AUC Score is {0:6f}".format(metrics.roc_auc_score(y_test, y_pred_sclf)))
# Out:
# Accuracy Score is 0.741697
# Precision Score is 0.781116
# Recall Score is 0.905473
# F1_score is 0.838710
# AUC Score is 0.588451

# %%
print(confusion_matrix(y_test, y_pred_sclf))
# Out:
# [[ 19  51]
#  [ 19 182]]

# %%
print(classification_report(y_test, y_pred_sclf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.27      0.35        70
#          1.0       0.78      0.91      0.84       201
#
#    micro avg       0.74      0.74      0.74       271
#    macro avg       0.64      0.59      0.60       271
# weighted avg       0.71      0.74      0.71       271

# %%
clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=50)
clf2 = GradientBoostingClassifier(learning_rate=0.03, n_estimators=100, max_depth= 3)
clf3 = BaggingClassifier(n_estimators=14)
rf = RandomForestClassifier(n_estimators=300)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf = sclf.fit(X_train, y_train)
y_probas = sclf.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_probas, plot_micro=False, plot_macro=False,figsize=(8,6))

clf1 = AdaBoostClassifier(learning_rate=0.6, n_estimators=50)
clf2 = GradientBoostingClassifier(learning_rate=0.03, n_estimators=100, max_depth= 3)
clf3 = BaggingClassifier(n_estimators=14)
rf = RandomForestClassifier(n_estimators=300)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=rf, use_features_in_secondary=True)
sclf = sclf.fit(X_train, y_train)
y_probas = sclf.predict_proba(X_test)
skplt.metrics.plot_lift_curve(y_test, y_probas,figsize=(8,6))

plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Model Performance after Tuning the Hyperparameters

# %%
clf1 = KNeighborsClassifier(leaf_size=3, n_neighbors=9)
clf2 = RandomForestClassifier(random_state=1, n_estimators=300)
clf3 = GaussianNB(var_smoothing=1e-12)
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)

# %%
# Dictionary of different classifiers
clfs = {
'LogisticRegression' : LogisticRegression(C=0.1),
'DecisionTree': DecisionTreeClassifier(max_depth=3, min_samples_leaf=8, min_samples_split=2),
'KNNClassifier': KNeighborsClassifier(leaf_size=3, n_neighbors=9),
'NaiveBayes': GaussianNB(var_smoothing=1e-12),
'SupportVectorMachines': SVC(kernel="linear", C=0.1, gamma=0.001),
'Bagging': BaggingClassifier(n_estimators=14),
'AdaBoostClassifier': AdaBoostClassifier(learning_rate=0.6, n_estimators=50),
'RandomForestClassifier': RandomForestClassifier(random_state=1, n_estimators=300),
'GradientBoostingClassifier': GradientBoostingClassifier(learning_rate=0.03, max_depth=3, n_estimators=100),
'XGBoost': XGBClassifier(),
'StackingClassifier': StackingClassifier(classifiers=[clf1, clf2, clf3],meta_classifier=lr, use_features_in_secondary=True)
}

# %%
# Testing all clfs models and generating a report
models_report = pd.DataFrame(columns = ['Model', 'Accuracy','Precision_score', 'Recall_score','F1_score', 'AUC'])

for clf, clf_name in zip(clfs.values(), clfs.keys()):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    y_score = clf.score(X_test,y_test)
    
    #print('Calculating {}'.format(clf_name))
    t = pd.Series({ 
                     'Model': clf_name,
                     'Precision_score': metrics.precision_score(y_test, y_pred),
                     'Recall_score': metrics.recall_score(y_test, y_pred),
                     'F1_score': metrics.f1_score(y_test, y_pred),
                     'Accuracy': metrics.accuracy_score(y_test, y_pred),
                     'AUC': metrics.roc_auc_score(y_test, y_pred)}
                   )

    models_report = models_report.append(t, ignore_index = True)

models_report
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                          Model  Accuracy  Precision_score  Recall_score  \
# 0           LogisticRegression  0.726937         0.749020      0.950249
# 1                 DecisionTree  0.723247         0.769231      0.895522
# 2                KNNClassifier  0.741697         0.749049      0.980100
# 3                   NaiveBayes  0.704797         0.768889      0.860697
# 4        SupportVectorMachines  0.738007         0.742537      0.990050
# 5                      Bagging  0.767528         0.816514      0.885572
# 6           AdaBoostClassifier  0.756458         0.794760      0.905473
# 7       RandomForestClassifier  0.774908         0.780000      0.970149
# 8   GradientBoostingClassifier  0.763838         0.779592      0.950249
# 9                      XGBoost  0.760148         0.783333      0.935323
# 10          StackingClassifier  0.774908         0.782258      0.965174
#
#     F1_score       AUC
# 0   0.837719  0.517982
# 1   0.827586  0.562047
# 2   0.849138  0.518621
# 3   0.812207  0.558920
# 4   0.848614  0.502168
# 5   0.849642  0.657072
# 6   0.846512  0.617022
# 7   0.864745  0.592217
# 8   0.856502  0.589410
# 9   0.852608  0.596233
# 10  0.864143  0.596873

# %%
# Even after tuning the hyperparameters, not much improvement is observed.

# %% [markdown]
# ## Part 2 Using a resampled dataset to solve the problem of imbalanced dataset with significant performance improvements across the algorithms

# %%
# Part II of this project utilizes a couple of techniques to solve the problem of imbalanced dataset, among which are:
#1. Ensemble Methods (also adopted here)
#2. Random oversampling of the undersampled class
#3. Hyperparameter tuning using GridSearch
#4 More visualizations such as the lift and roc curves
#5 Artificial Neural Network
#6 Feauture Selection and Importance

# %% [markdown]
# ## Disclaimer

# %%
# The content of this publication is intended for information and education purposes only. It is very important to do your own 
# analysis before making any investment decision based on your own personal circumstances. You should take independent
# financial advice from a professional in connection with, or independently research and verify, any information you find in
# this publication and wish to rely upon, whether for the purpose of making investment decision or otherwise.
